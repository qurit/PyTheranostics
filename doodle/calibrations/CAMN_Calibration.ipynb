# %%
from doodle.calibrations.gamma_camera import GammaCamera
import matplotlib.pyplot as plt #for visualization and plots
import numpy as np

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
isotope = 'Lu177'

# %%
site_id = 'CAMN'

# %%
db_dic = {
    'db_file':'/mnt/y/Sara/PR21_enrolment/PR21_DB.xlsx',
    'sheet_names':['calibration_data'],
    'header':0,
}

# %%
symbia_cal_file = f'/mnt/y/Sara/PR21_enrolment/{site_id}2/optima1/source_c/1.2.826.0.1.3680043.10.740.1855716350417343378088572792475151674.dcm'

# %% [markdown]
# ## Sensitivity Calculation

# %%
Camera = GammaCamera(isotope=isotope,dicomfile=symbia_cal_file,db_dic=db_dic,cal_type='planar')

# %%
Camera.db_df['cal_data']
# Out:
#     site_id                  department       city  \
# 0      CAVA  Vancouver General Hospital  Vancouver
# 1      CAVA  Vancouver General Hospital  Vancouver
# 2      CAVA  Vancouver General Hospital  Vancouver
# 3      CAVA  Vancouver General Hospital  Vancouver
# 4      CAVA  Vancouver General Hospital  Vancouver
# ..      ...                         ...        ...
# 148    CATC    Foothills Medical Centre    Calgary
# 149    CATC    Foothills Medical Centre    Calgary
# 150    CATC    Foothills Medical Centre    Calgary
# 151    CATC    Foothills Medical Centre    Calgary
# 152    CATC    Foothills Medical Centre    Calgary
#
#                                performed_by cal_type manufacturer  \
# 0                                   Minh Lu       dc       Biodex
# 1                                   Minh Lu       dc       Biodex
# 2                                   Minh Lu       dc       Biodex
# 3                                   Minh Lu       dc       Biodex
# 4                                   Minh Lu       dc       Biodex
# ..                                      ...      ...          ...
# 148  Stephanie Bnukworth + Ralph Zimmermann   planar           GE
# 149  Stephanie Bnukworth + Ralph Zimmermann   planar           GE
# 150  Stephanie Bnukworth + Ralph Zimmermann   planar           GE
# 151  Stephanie Bnukworth + Ralph Zimmermann   planar           GE
# 152  Stephanie Bnukworth + Ralph Zimmermann    spect           GE
#
#                 model collimator initial_ cal_num      source_id  ...  Am_MBq  \
# 0    Atomlab 100 Plus        NaN              107              A  ...  6460.0
# 1    Atomlab 100 Plus        NaN              107              B  ...  1812.0
# 2    Atomlab 100 Plus        NaN              107              C  ...    14.5
# 3    Atomlab 100 Plus        NaN              107  syringe_20_mL  ...     NaN
# 4    Atomlab 500 Plus        NaN              117              A  ...  6460.0
# ..                ...        ...              ...            ...  ...     ...
# 148     Discovery 670       MEGP              NaN              C  ...     NaN
# 149     Discovery 670       MEGP              NaN              A  ...     NaN
# 150     Discovery 670       MEGP              NaN              B  ...     NaN
# 151     Discovery 670       MEGP              NaN            A+B  ...     NaN
# 152     Discovery 670       MEGP              NaN          A+B+C  ...     NaN
#
#     Ai_syr_MBq Af_syr_MBq  As_syr_MBq  syringe_activity_calculated  \
# 0          NaN        NaN         NaN                          NaN
# 1          NaN        NaN         NaN                          NaN
# 2          NaN        NaN         NaN                          NaN
# 3       6460.0      265.0      6195.0                       6195.0
# 4          NaN        NaN         NaN                          NaN
# ..         ...        ...         ...                          ...
# 148        NaN        NaN         NaN                          NaN
# 149        NaN        NaN         NaN                          NaN
# 150        NaN        NaN         NaN                          NaN
# 151        NaN        NaN         NaN                          NaN
# 152        NaN        NaN         NaN                          NaN
#
#      Am_syr_MBq  reported_recovery  recovery_calculated  final_cal_num  \
# 0           NaN               99.7                 99.8            114
# 1           NaN               99.9                100.0            120
# 2           NaN              100.0                101.0            112
# 3        6190.0               99.9                 99.9            111
# 4           NaN               99.7                 99.9            125
# ..          ...                ...                  ...            ...
# 148         NaN                NaN                  NaN            NaN
# 149         NaN                NaN                  NaN            NaN
# 150         NaN                NaN                  NaN            NaN
# 151         NaN                NaN                  NaN            NaN
# 152         NaN                NaN                  NaN            NaN
#
#      comments
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 148       NaN
# 149       NaN
# 150       NaN
# 151       NaN
# 152       NaN
#
# [153 rows x 28 columns]

# %%
Camera.get_sensitivity(site_id = site_id)
# Out:
# The activity of the source at the time of the scan was 19.482731301409867 MBq
#
# Info about the different energy windows and detectors:
# {'general_scatter': {'center': 110.0,
#                      'counts': {'Detector1': 82886, 'Detector2': 85199},
#                      'lower': '55.0',
#                      'upper': '165.0',
#                      'width': 110.0},
#  'low_scatter': {'center': 176.62,
#                  'counts': {'Detector1': 5172, 'Detector2': 5843},
#                  'lower': '166.37',
#                  'upper': '186.88',
#                  'width': 20.50999999999999},
#  'photopeak': {'center': 208.0,
#                'counts': {'Detector1': 38042, 'Detector2': 38987},
#                'lower': '187.2',
#                'upper': '228.8',
#                'width': 41.60000000000002},
#  'upper_scatter': {'center': 239.31,
#                    'counts': {'Detector1': 3468, 'Detector2': 3613},
#                    'lower': '228.91',
#                    'upper': '249.72',
#                    'width': 20.810000000000002}}
#
#
# Primary counts in each detector
# {'Detector1': 29330.537301221535, 'Detector2': 29450.11941222047}
#
#
# Calibration Results. Sensitivity in cps/MBq. Calibration factor in MBq/cps
# {'CAMN': {'Optima 640': {'calibration_factor': {'Average': 0.1988688019909911,
#                                                 'Detector1': 0.1992742011643796,
#                                                 'Detector2': 0.19846504893958508},
#                          'collimator': 'MEGP',
#                          'manufacturer': 'GE',
#                          'sensitivity': {'Average': 5.028440811170073,
#                                          'Detector1': 5.018211058716569,
#                                          'Detector2': 5.038670563623577}}}}

# %%
Camera.calfactor_to_database(site_id = site_id)

# %% [markdown]
# ## Conclusion & Comments

# %% [markdown]
# The calibration factors for the submitted data were:
#
# 1) GE Camera: 0.2 MBq/cps
#
# No issues were detected

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# <p style='text-align: right;'> Carlos Uribe, PhD, MCCPM <br>
# Medical Imaging Physicist <br>
# BC Cancer</p>
