# %%
from doodle.calibrations.gamma_camera import GammaCamera
import matplotlib.pyplot as plt #for visualization and plots
import numpy as np

# %load_ext autoreload
# %autoreload 2

# %%
isotope = 'Lu177'

# %%
site_id = 'CAGA'

# %%
db_dic = {
    'db_file':'/mnt/y/Sara/PR21_enrolment/PR21_DB.xlsx',
    'sheet_names':['calibration_data'],
    'header':0,
}

# %%
symbia_cal_file = f'/mnt/y/Sara/PR21_enrolment/{site_id}/source_a/2.16.840.1.114362.1.11940992.23790159890.586488709.517.571.dcm'

# %% [markdown]
# ## Sensitivity Calculation

# %%
Camera = GammaCamera(isotope=isotope,dicomfile=symbia_cal_file,db_dic=db_dic,cal_type='planar')

# %%
Camera.db_df['cal_data']
# Out:
#     site_id                  department       city  \
# 0      CAVA  Vancouver General Hospital  Vancouver
# 1      CAVA  Vancouver General Hospital  Vancouver
# 2      CAVA  Vancouver General Hospital  Vancouver
# 3      CAVA  Vancouver General Hospital  Vancouver
# 4      CAVA  Vancouver General Hospital  Vancouver
# ..      ...                         ...        ...
# 162    CATC    Foothills Medical Centre    Calgary
# 163    CATC    Foothills Medical Centre    Calgary
# 164    CATC    Foothills Medical Centre    Calgary
# 165    CATC    Foothills Medical Centre    Calgary
# 166    CATC    Foothills Medical Centre    Calgary
#
#                                performed_by cal_type manufacturer  \
# 0                                   Minh Lu       dc       Biodex
# 1                                   Minh Lu       dc       Biodex
# 2                                   Minh Lu       dc       Biodex
# 3                                   Minh Lu       dc       Biodex
# 4                                   Minh Lu       dc       Biodex
# ..                                      ...      ...          ...
# 162  Stephanie Bnukworth + Ralph Zimmermann   planar           GE
# 163  Stephanie Bnukworth + Ralph Zimmermann   planar           GE
# 164  Stephanie Bnukworth + Ralph Zimmermann   planar           GE
# 165  Stephanie Bnukworth + Ralph Zimmermann   planar           GE
# 166  Stephanie Bnukworth + Ralph Zimmermann    spect           GE
#
#                 model collimator initial_ cal_num      source_id  ...  Am_MBq  \
# 0    Atomlab 100 Plus        NaN              107              A  ...  6460.0
# 1    Atomlab 100 Plus        NaN              107              B  ...  1812.0
# 2    Atomlab 100 Plus        NaN              107              C  ...    14.5
# 3    Atomlab 100 Plus        NaN              107  syringe_20_mL  ...     NaN
# 4    Atomlab 500 Plus        NaN              117              A  ...  6460.0
# ..                ...        ...              ...            ...  ...     ...
# 162     Discovery 670       MEGP              NaN              C  ...     NaN
# 163     Discovery 670       MEGP              NaN              A  ...     NaN
# 164     Discovery 670       MEGP              NaN              B  ...     NaN
# 165     Discovery 670       MEGP              NaN            A+B  ...     NaN
# 166     Discovery 670       MEGP              NaN          A+B+C  ...     NaN
#
#     Ai_syr_MBq Af_syr_MBq  As_syr_MBq  syringe_activity_calculated  \
# 0          NaN        NaN         NaN                          NaN
# 1          NaN        NaN         NaN                          NaN
# 2          NaN        NaN         NaN                          NaN
# 3       6460.0      265.0      6195.0                       6195.0
# 4          NaN        NaN         NaN                          NaN
# ..         ...        ...         ...                          ...
# 162        NaN        NaN         NaN                          NaN
# 163        NaN        NaN         NaN                          NaN
# 164        NaN        NaN         NaN                          NaN
# 165        NaN        NaN         NaN                          NaN
# 166        NaN        NaN         NaN                          NaN
#
#      Am_syr_MBq  reported_recovery  recovery_calculated  final_cal_num  \
# 0           NaN               99.7                 99.8            114
# 1           NaN               99.9                100.0            120
# 2           NaN              100.0                101.0            112
# 3        6190.0               99.9                 99.9            111
# 4           NaN               99.7                 99.9            125
# ..          ...                ...                  ...            ...
# 162         NaN                NaN                  NaN            NaN
# 163         NaN                NaN                  NaN            NaN
# 164         NaN                NaN                  NaN            NaN
# 165         NaN                NaN                  NaN            NaN
# 166         NaN                NaN                  NaN            NaN
#
#      comments
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 162       NaN
# 163       NaN
# 164       NaN
# 165       NaN
# 166       NaN
#
# [167 rows x 28 columns]

# %%
Camera.get_sensitivity(site_id = site_id)
# Out:
# The activity of the source at the time of the scan was 14.464874766603403 MBq
#
# Info about the different energy windows and detectors:
# {'general_scatter': {'center': 110.93,
#                      'counts': {'Detector1': 110101, 'Detector2': 108582},
#                      'lower': '55.465000152588',
#                      'upper': '166.39500427246',
#                      'width': 110.930004119872},
#  'low_scatter': {'center': 176.8,
#                  'counts': {'Detector1': 5656, 'Detector2': 5599},
#                  'lower': '166.39999389648',
#                  'upper': '187.19999694824',
#                  'width': 20.80000305176},
#  'photopeak': {'center': 208.0,
#                'counts': {'Detector1': 50071, 'Detector2': 49335},
#                'lower': '187.19999694824',
#                'upper': '228.80000305176',
#                'width': 41.60000610352},
#  'upper_scatter': {'center': 239.2,
#                    'counts': {'Detector1': 2991, 'Detector2': 3053},
#                    'lower': '228.80000305176',
#                    'upper': '249.60000610352',
#                    'width': 20.80000305176}}
#
#
# Primary counts in each detector
# {'Detector1': 41424.0, 'Detector2': 40683.0}
#
#
# Calibration Results. Sensitivity in cps/MBq. Calibration factor in MBq/cps
# {'CAGA': {'Intevo T6': {'calibration_factor': {'Average': 0.10570332273084035,
#                                                'Detector1': 0.10475790265861708,
#                                                'Detector2': 0.1066659626804944},
#                         'collimator': 'MEGL',
#                         'manufacturer': 'Siemens',
#                         'sensitivity': {'Average': 9.460440544015526,
#                                         'Detector1': 9.545819213838021,
#                                         'Detector2': 9.375061874193033}}}}

# %%
Camera.calfactor_to_database(site_id = site_id)

# %% [markdown]
# ## Conclusion & Comments

# %% [markdown]
# The calibration factors for the submitted data were:
#
# 1) Siemens Intevo T6: 0.11 MBq/cps
#
# No issues were detected

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# <p style='text-align: right;'> Carlos Uribe, PhD, MCCPM <br>
# Medical Imaging Physicist <br>
# BC Cancer</p>
