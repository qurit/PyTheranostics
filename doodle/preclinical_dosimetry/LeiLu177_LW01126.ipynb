# %%
date='17-01-2023' 
isotope='Lu177'
tracer='GRPRtargeting'
cell_line='PC3'
mouse_type='NRG'
biodi_author='LeiWang-LW01126'
biodi_file = '/mnt/y/Sara/Preclinical_dosimetry/Lei/20230111_Lu177_LW01126_all time points_new.csv'

# %%
import pandas as pd
import numpy as np
from numpy import exp,log

import os

from biodose import BioDose

# This allows external modification of .py and automatic module reload:
# %load_ext autoreload
# %autoreload 2
# To generate the plots within the notebook
# %matplotlib inline

# %%
Isotope = 'Lu-177'
half_life = 159.528 #hours

# %%
t = np.array([1, 4, 24, 72, 120])  #hours

# %%
mouse=BioDose(isotope=Isotope,half_life=half_life,phantom='Mouse25g',sex='Male',timepoints=t)

# %%
mouse.read_biodi(biodi_file)
mouse.biodi.dropna(inplace=True)
mouse.biodi
# Out:
# Reading biodistribution information from the file: /mnt/y/Sara/Preclinical_dosimetry/Lei/20230111_Lu177_LW01126_all time points_new.csv
# Raw biodi (all data at injection time) available in self.raw_biodi
# Decay factors for this isotope at given times are
#  [0.99566 0.98277 0.90097 0.73137 0.59369]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/skurkowska/doodle/doodle/preclinical_dosimetry/LeiLu177_LW01126.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/skurkowska/doodle/doodle/preclinical_dosimetry/LeiLu177_LW01126.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> mouse.read_biodi(biodi_file)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/skurkowska/doodle/doodle/preclinical_dosimetry/LeiLu177_LW01126.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> mouse.biodi.dropna(inplace=True)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/skurkowska/doodle/doodle/preclinical_dosimetry/LeiLu177_LW01126.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> mouse.biodi
#
# File ~/doodle/doodle/preclinical_dosimetry/biodose.py:84, in BioDose.read_biodi(self, biodi_file)
#      82 print("Decay factors for this isotope at given times are\n", decay_factor)
#      83 self.biodi['%ID/g'] = np.round(biodi['%ID/g']*decay_factor,5)
# ---> 84 self.biodi['sigma'] = np.round(biodi['sigma']*decay_factor,5)
#      85 print('Decayed biodistribution stored in self.biodi')
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:202, in OpsMixin.__mul__(self, other)
#     200 @unpack_zerodim_and_defer("__mul__")
#     201 def __mul__(self, other):
# --> 202     return self._arith_method(other, operator.mul)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:7455, in DataFrame._arith_method(self, other, op)
#    7452 axis: Literal[1] = 1  # only relevant for Series other case
#    7453 other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
# -> 7455 self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    7457 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7458 return self._construct_result(new_data)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/__init__.py:260, in align_method_FRAME(left, right, axis, flex, level)
#     258 if isinstance(right, np.ndarray):
#     259     if right.ndim == 1:
# --> 260         right = to_series(right)
#     262     elif right.ndim == 2:
#     263         # We need to pass dtype=right.dtype to retain object dtype
#     264         #  otherwise we lose consistency with Index and array ops
#     265         dtype = None
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/__init__.py:252, in align_method_FRAME.<locals>.to_series(right)
#     250 else:
#     251     if len(left.columns) != len(right):
# --> 252         raise ValueError(
#     253             msg.format(req_len=len(left.columns), given_len=len(right))
#     254         )
#     255     right = left._constructor_sliced(right, index=left.columns, dtype=dtype)
#     256 return right
#
# ValueError: Unable to coerce to Series, length must be 37: given 5

# %%
mouse.curve_fits()
# Out:
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# /home/skurkowska/doodle/doodle/plots/plots.py:37: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(1, 3, figsize=(10,4))
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere

# %%
mouse.area
# Out:
#                 Mono-Exponential Bi-Exponential Bi-Exponential_uptake  \
# Adrenals               85.224941      69.411767                   NaN
# Bladder              1298.261881    1435.901096                   NaN
# Blood                   1.883606       1.883608                   NaN
# Brain                    0.55833       0.376139                   NaN
# Fat                     0.219541        0.40023                   NaN
# Heart                   0.798586      12.847022                   NaN
# Kidneys                92.590031     105.470542                   NaN
# Large Intestine         52.03596      36.479438                   NaN
# Liver                   6.891064      10.756301                   NaN
# Lungs                  15.909553      12.837762                   NaN
# Muscle                  0.532315       1.363807                   NaN
# Pancreas               63.137727     213.519483                   NaN
# Seminals               14.065454      14.063599                   NaN
# Skeleton                0.575425       2.316303                   NaN
# Small Intestine         7.179167      22.135781                   NaN
# Spleen                 10.487346       14.53552                   NaN
# Stomach                 4.630692      14.831191                   NaN
# Tail                     9.86056      27.154615                   NaN
# Testes                  1.029986       2.927772                   NaN
# Tumor                  595.05088     591.588248                   NaN
#
#                 Tri-Exponential Perctage_diff - mono vs bi washout  \
# Adrenals                    NaN                          18.554632
# Bladder                     NaN                          10.601807
# Blood                       NaN                           0.000098
# Brain                       NaN                           32.63146
# Fat                         NaN                          82.303144
# Heart                       NaN                        1508.721831
# Kidneys                     NaN                          13.911336
# Large Intestine             NaN                          29.895716
# Liver                       NaN                           56.09057
# Lungs                       NaN                           19.30784
# Muscle                      NaN                         156.202854
# Pancreas                    NaN                         238.180502
# Seminals                    NaN                           0.013189
# Skeleton                    NaN                         302.537639
# Small Intestine             NaN                         208.333562
# Spleen                      NaN                          38.600567
# Stomach                     NaN                          220.28023
# Tail                        NaN                          175.38614
# Testes                      NaN                         184.253708
# Tumor                       NaN                           0.581905
#
#                 Perctage_diff - bi vs tri uptake washout
# Adrenals                                             NaN
# Bladder                                              NaN
# Blood                                                NaN
# Brain                                                NaN
# Fat                                                  NaN
# Heart                                                NaN
# Kidneys                                              NaN
# Large Intestine                                      NaN
# Liver                                                NaN
# Lungs                                                NaN
# Muscle                                               NaN
# Pancreas                                             NaN
# Seminals                                             NaN
# Skeleton                                             NaN
# Small Intestine                                      NaN
# Spleen                                               NaN
# Stomach                                              NaN
# Tail                                                 NaN
# Testes                                               NaN
# Tumor                                                NaN

# %%
mouse.curve_fits(organlist=['Large Intestine'],uptake=True,append_zero=True, uptakeguess=(10,0.01,-100,1))

# %%
mouse.area
# Out:
#                 Mono-Exponential Bi-Exponential Bi-Exponential_uptake  \
# Adrenals               85.224941      69.411767                   NaN
# Bladder              1298.261881    1435.901096                   NaN
# Blood                   1.883606       1.883608                   NaN
# Brain                    0.55833       0.376139                   NaN
# Fat                     0.219541        0.40023                   NaN
# Heart                   0.798586      12.847022                   NaN
# Kidneys                92.590031     105.470542                   NaN
# Large Intestine         52.03596      36.479438             37.852397
# Liver                   6.891064      10.756301                   NaN
# Lungs                  15.909553      12.837762                   NaN
# Muscle                  0.532315       1.363807                   NaN
# Pancreas               63.137727     213.519483                   NaN
# Seminals               14.065454      14.063599                   NaN
# Skeleton                0.575425       2.316303                   NaN
# Small Intestine         7.179167      22.135781                   NaN
# Spleen                 10.487346       14.53552                   NaN
# Stomach                 4.630692      14.831191                   NaN
# Tail                     9.86056      27.154615                   NaN
# Testes                  1.029986       2.927772                   NaN
# Tumor                  595.05088     591.588248                   NaN
#
#                 Tri-Exponential Perctage_diff - mono vs bi washout  \
# Adrenals                    NaN                          18.554632
# Bladder                     NaN                          10.601807
# Blood                       NaN                           0.000098
# Brain                       NaN                           32.63146
# Fat                         NaN                          82.303144
# Heart                       NaN                        1508.721831
# Kidneys                     NaN                          13.911336
# Large Intestine             NaN                          29.895716
# Liver                       NaN                           56.09057
# Lungs                       NaN                           19.30784
# Muscle                      NaN                         156.202854
# Pancreas                    NaN                         238.180502
# Seminals                    NaN                           0.013189
# Skeleton                    NaN                         302.537639
# Small Intestine             NaN                         208.333562
# Spleen                      NaN                          38.600567
# Stomach                     NaN                          220.28023
# Tail                        NaN                          175.38614
# Testes                      NaN                         184.253708
# Tumor                       NaN                           0.581905
#
#                 Perctage_diff - bi vs tri uptake washout
# Adrenals                                             NaN
# Bladder                                              NaN
# Blood                                                NaN
# Brain                                                NaN
# Fat                                                  NaN
# Heart                                                NaN
# Kidneys                                              NaN
# Large Intestine                                      NaN
# Liver                                                NaN
# Lungs                                                NaN
# Muscle                                               NaN
# Pancreas                                             NaN
# Seminals                                             NaN
# Skeleton                                             NaN
# Small Intestine                                      NaN
# Spleen                                               NaN
# Stomach                                              NaN
# Tail                                                 NaN
# Testes                                               NaN
# Tumor                                                NaN

# %%
fit_accepted={'Adrenals':1,
              'Bladder':2,
              'Blood':1,
              'Brain':1,
              'Fat':1,
              'Heart':1,
              'Kidneys':2,
              'Large Intestine':1,
              'Liver':2,
              'Lungs':2,
              'Muscle':1,
              'Pancreas':2,
              'Seminals':1,
              'Skeleton':2,
              'Small Intestine':2,
              'Spleen':2,
              'Stomach':2,
              'Tail':2,
              'Testes':2,
              'Tumor':2,                       
             }

# %%
mouse.num_decays(fit_accepted)
mouse.disintegrations
# Out:
#                      %ID/g*h
# Organ
# Adrenals           69.411767
# Bladder          1435.901096
# Blood               1.883608
# Brain                0.55833
# Fat                  0.40023
# Heart              12.847022
# Kidneys           105.470542
# Large Intestine    37.852397
# Liver              10.756301
# Lungs              12.837762
# Muscle              0.532315
# Pancreas          213.519483
# Seminals           14.063599
# Skeleton            2.316303
# Small Intestine    22.135781
# Spleen              14.53552
# Stomach             4.630692
# Tail               27.154615
# Testes              2.927772
# Tumor             591.588248
# Remainder Body           NaN

# %%
mouse.phantom_data()
mouse.add_tumor_mass('Tumor',0.2925) 
mouse.phantom_mass
# Out:
# /home/skurkowska/doodle/doodle/preclinical_dosimetry/phantomdata
# These organs from the biodi are not modelled in the phantom
# ['Adrenals', 'Blood', 'Fat', 'Muscle', 'Seminals', 'Tail', 'Tumor']
#
# These organs modelled in the phantom were not included in the biodistribution.
# ['Thyroid']
#                      25g      30g      35g
# Organ
# Bladder           0.0600   0.0750   0.0880
# Body             24.1100  29.8000  35.2700
# Brain             0.4660   0.5680   0.6660
# Heart             0.2350   0.2910   0.3420
# Kidneys           0.3020   0.3740   0.4320
# Large Intestine   0.5830   0.7090   0.8300
# Liver             1.7400   2.1500   2.5700
# Lungs             0.0870   0.1070   0.1310
# Pancreas          0.3050   0.3780   0.4500
# Skeleton          2.1800   2.6100   3.0100
# Small Intestine   1.7400   2.1200   2.4900
# Spleen            0.1110   0.1360   0.1570
# Stomach           0.0550   0.0690   0.0820
# Testes            0.1600   0.1970   0.2280
# Thyroid           0.0140   0.0160   0.0200
# Remainder Body   16.0860  20.0160  23.7940
# Tumor             0.2925   0.2925   0.2925

# %%
mouse.remainder_body_uptake(tumor_name='Tumor')
# Out:
# At this point we are ignoring the tumor
# Mouse25g
# Disintegrations
#
#
# Literature Mass (g)
#
#                25g       30g       35g
# Organ
# Adrenals  0.010200  0.010200  0.010200
# Blood     2.400000  2.400000  2.400000
# Fat       6.500000  7.800000  9.100000
# Muscle    4.545755  7.175755  9.653755
# Seminals  0.173045  0.173045  0.173045
#                      25g      30g      35g
# Organ
# Bladder           0.0600   0.0750   0.0880
# Body             24.1100  29.8000  35.2700
# Brain             0.4660   0.5680   0.6660
# Heart             0.2350   0.2910   0.3420
# Kidneys           0.3020   0.3740   0.4320
# Large Intestine   0.5830   0.7090   0.8300
# Liver             1.7400   2.1500   2.5700
# Lungs             0.0870   0.1070   0.1310
# Pancreas          0.3050   0.3780   0.4500
# Skeleton          2.1800   2.6100   3.0100
# Small Intestine   1.7400   2.1200   2.4900
# Spleen            0.1110   0.1360   0.1570
# Stomach           0.0550   0.0690   0.0820
# Testes            0.1600   0.1970   0.2280
# Thyroid           0.0140   0.0160   0.0200
# Remainder Body   16.0860  20.0160  23.7940
# Tumor             0.2925   0.2925   0.2925

# %%
mouse.disintegrations
# Out:
#                    %ID/g*h     %ID*h
# Organ
# Bladder          14.359011  0.861541
# Brain             0.005583  0.002602
# Heart              0.12847  0.030191
# Kidneys           1.054705  0.318521
# Large Intestine   0.378524  0.220679
# Liver             0.107563   0.18716
# Lungs             0.128378  0.011169
# Pancreas          2.135195  0.651234
# Skeleton          0.023163  0.050495
# Small Intestine   0.221358  0.385163
# Spleen            0.145355  0.016134
# Stomach           0.046307  0.002547
# Testes            0.029278  0.004684
# Tumor             5.915882  1.730396
# Remainder Body         NaN  0.126836

# %%
mouse.tumor_sink_effect()
mouse.disintegrations
# Out:
# <class 'pandas.core.series.Series'>
#                    %ID/g*h     %ID*h
# Organ
# Bladder          14.359011  1.381174
# Brain             0.005583  0.004171
# Heart              0.12847    0.0484
# Kidneys           1.054705  0.510635
# Large Intestine   0.378524  0.353781
# Liver             0.107563  0.300044
# Lungs             0.128378  0.017905
# Pancreas          2.135195  1.044023
# Skeleton          0.023163  0.080951
# Small Intestine   0.221358  0.617471
# Spleen            0.145355  0.025866
# Stomach           0.046307  0.004083
# Testes            0.029278   0.00751
# Tumor             5.915882  1.730396
# Remainder Body         NaN  0.203336

# %%
dirname='/mnt/y/Sara/Preclinical_dosimetry/{}_{}_{}_{}_{}_{}_updated'.format(cell_line,date,isotope,tracer,mouse_type,biodi_author)
dirname
# Out:
# '/mnt/y/Sara/Preclinical_dosimetry/PC3_17-01-2023_Lu177_GRPRtargeting_NRG_LeiWang-LW01110_updated'

# %%
mouse.create_mouse25case(savefile=True,dirname=dirname)
# Out:
# The case file mouse25g.cas has been saved in
# /mnt/y/Sara/Preclinical_dosimetry/PC3_17-01-2023_Lu177_GRPRtargeting_NRG_LeiWang-LW01110_updated

# %%
mouse.biodi
# Out:
#                      %ID/g                                           sigma  \
#                    1_%ID/g   4_%ID/g 23_%ID/g 72_%ID/g 120_%ID/g      1_sd
# Organ
# Adrenals           1.21860   0.99927  1.12430  0.34771   0.14619   0.37606
# Bladder          384.95699  91.63017  2.11668  0.73627   0.23970  41.36483
# Blood              0.69051   0.04390  0.00525  0.00260   0.00068   0.05501
# Brain              0.02803   0.03386  0.00428  0.00330   0.00124   0.00418
# Fat                0.07236   0.01191  0.00920  0.00345   0.00083   0.01556
# Heart              0.21790   0.06327  0.02654  0.01113   0.00370   0.00888
# Kidneys            3.75135   3.38471  1.31287  0.38175   0.11735   0.57253
# Large Intestine    0.99786   1.13294  0.40070  0.44990   0.06385   0.14737
# Liver              0.40321   0.22955  0.11789  0.04881   0.02301   0.04718
# Lungs              0.69079   1.00689  0.10857  0.04732   0.01751   0.11745
# Muscle             0.14499   0.04227  0.00982  0.00459   0.00201   0.01659
# Pancreas          11.09225   5.46528  2.79448  0.75093   0.20228   1.36491
# Seminals           4.20759   0.01971  0.00941  0.00702   0.00167   7.27829
# Skeleton           0.13848   0.05019  0.02051  0.01349   0.00427   0.05369
# Small Intestine    2.00027   0.55514  0.26700  0.06339   0.01786   0.12820
# Spleen             0.27644   0.14669  0.10917  0.07320   0.02818   0.04545
# Stomach            0.98853   0.41853  0.15037  0.05844   0.02167   0.21256
# Tail               0.75861   0.46561  0.16270  0.13648   0.07355   0.22129
# Testes             0.23333   0.09218  0.02195  0.01373   0.00487   0.03852
# Tumor             10.94848   9.87378  6.21516  3.45102   1.32270   1.02787
#
#
#                      4_sd    23_sd    72_sd   120_sd
# Organ
# Adrenals          0.32472  0.56799  0.10859  0.03144
# Bladder          47.23843  1.13020  0.31368  0.07244
# Blood             0.01148  0.00148  0.00083  0.00049
# Brain             0.02040  0.00081  0.00191  0.00050
# Fat               0.00482  0.00398  0.00178  0.00020
# Heart             0.05634  0.00444  0.00295  0.00075
# Kidneys           1.75951  0.37988  0.07283  0.01281
# Large Intestine   0.36887  0.09764  0.62919  0.02617
# Liver             0.06975  0.03473  0.00434  0.00544
# Lungs             1.75940  0.10927  0.01945  0.01904
# Muscle            0.03928  0.00294  0.00306  0.00101
# Pancreas          1.53829  0.43643  0.21607  0.02395
# Seminals          0.00896  0.00202  0.00559  0.00085
# Skeleton          0.02503  0.00572  0.00457  0.00133
# Small Intestine   0.19545  0.08887  0.02042  0.00238
# Spleen            0.03338  0.01655  0.01490  0.00497
# Stomach           0.15284  0.06565  0.01698  0.01049
# Tail              0.17001  0.04855  0.06715  0.01378
# Testes            0.08308  0.00648  0.00363  0.00115
# Tumor             1.37335  1.21169  1.03570  0.19321

# %%
human = mouse.humanize_biodi(small_intestine=False)
# Out:
#                       %ID/g                                           \
#                     1_%ID/g    4_%ID/g  23_%ID/g  72_%ID/g 120_%ID/g
# Adrenals           1.218600   0.999270  1.124300  0.347710  0.146190
# Bladder          384.956990  91.630170  2.116680  0.736270  0.239700
# Bone Surfaces      0.138480   0.050190  0.020510  0.013490  0.004270
# Brain              0.028030   0.033860  0.004280  0.003300  0.001240
# Fat                0.072360   0.011910  0.009200  0.003450  0.000830
# Heart              0.217900   0.063270  0.026540  0.011130  0.003700
# Heart Contents     0.690510   0.043900  0.005250  0.002600  0.000680
# Kidneys            3.751350   3.384710  1.312870  0.381750  0.117350
# Left Colon         0.997860   1.132940  0.400700  0.449900  0.063850
# Liver              0.403210   0.229550  0.117890  0.048810  0.023010
# Lungs              0.690790   1.006890  0.108570  0.047320  0.017510
# Muscle             0.144990   0.042270  0.009820  0.004590  0.002010
# Pancreas          11.092250   5.465280  2.794480  0.750930  0.202280
# Rectum             0.997860   1.132940  0.400700  0.449900  0.063850
# Red Marrow         0.234773   0.014926  0.001785  0.000884  0.000231
# Right Colon        0.997860   1.132940  0.400700  0.449900  0.063850
# Seminals           4.207590   0.019710  0.009410  0.007020  0.001670
# Small Intestine    0.997860   1.132940  0.400700  0.449900  0.063850
# Spleen             0.276440   0.146690  0.109170  0.073200  0.028180
# Stomach            0.988530   0.418530  0.150370  0.058440  0.021670
# Tail               0.758610   0.465610  0.162700  0.136480  0.073550
# Testes             0.233330   0.092180  0.021950  0.013730  0.004870
# Tumor             10.948480   9.873780  6.215160  3.451020  1.322700
#
#                      sigma
#                       1_sd       4_sd     23_sd     72_sd    120_sd
# Adrenals          0.376060   0.324720  0.567990  0.108590  0.031440
# Bladder          41.364830  47.238430  1.130200  0.313680  0.072440
# Bone Surfaces     0.053690   0.025030  0.005720  0.004570  0.001330
# Brain             0.004180   0.020400  0.000810  0.001910  0.000500
# Fat               0.015560   0.004820  0.003980  0.001780  0.000200
# Heart             0.008880   0.056340  0.004440  0.002950  0.000750
# Heart Contents    0.055010   0.011480  0.001480  0.000830  0.000490
# Kidneys           0.572530   1.759510  0.379880  0.072830  0.012810
# Left Colon        0.147370   0.368870  0.097640  0.629190  0.026170
# Liver             0.047180   0.069750  0.034730  0.004340  0.005440
# Lungs             0.117450   1.759400  0.109270  0.019450  0.019040
# Muscle            0.016590   0.039280  0.002940  0.003060  0.001010
# Pancreas          1.364910   1.538290  0.436430  0.216070  0.023950
# Rectum            0.147370   0.368870  0.097640  0.629190  0.026170
# Red Marrow        0.018703   0.003903  0.000503  0.000282  0.000167
# Right Colon       0.147370   0.368870  0.097640  0.629190  0.026170
# Seminals          7.278290   0.008960  0.002020  0.005590  0.000850
# Small Intestine   0.147370   0.368870  0.097640  0.629190  0.026170
# Spleen            0.045450   0.033380  0.016550  0.014900  0.004970
# Stomach           0.212560   0.152840  0.065650  0.016980  0.010490
# Tail              0.221290   0.170010  0.048550  0.067150  0.013780
# Testes            0.038520   0.083080  0.006480  0.003630  0.001150
# Tumor             1.027870   1.373350  1.211690  1.035700  0.193210

# %%
human.fit_accepted
# Out:
# {'Adrenals': 2,
#  'Bladder': 2,
#  'Heart Contents': 2,
#  'Red Marrow': 2,
#  'Brain': 1,
#  'Fat': 2,
#  'Heart': 2,
#  'Kidneys': 2,
#  'Left Colon': 3,
#  'Right Colon': 3,
#  'Rectum': 3,
#  'Liver': 2,
#  'Lungs': 2,
#  'Muscle': 1,
#  'Pancreas': 2,
#  'Seminals': 2,
#  'Bone Surfaces': 2,
#  'Small Intestine': 2,
#  'Spleen': 2,
#  'Stomach': 1,
#  'Tail': 2,
#  'Testes': 2,
#  'Tumor': 2}

# %%
human.num_decays(human.fit_accepted)
human.disintegrations
# Out:
#                      %ID/g*h
# Adrenals           69.411767
# Bladder          1435.901096
# Bone Surfaces       2.316303
# Brain                0.55833
# Fat                  0.40023
# Heart              12.847022
# Heart Contents      1.883608
# Kidneys           105.470542
# Left Colon         37.852397
# Liver              10.756301
# Lungs              12.837762
# Muscle              0.532315
# Pancreas          213.519483
# Rectum             37.852397
# Red Marrow          0.640427
# Right Colon        37.852397
# Seminals           14.063599
# Small Intestine    22.135781
# Spleen              14.53552
# Stomach             4.630692
# Tail               27.154615
# Testes              2.927772
# Tumor             591.588248
# Remainder Body           NaN

# %%
human.phantom_data()
human.phantom_mass
# Out:
# /home/skurkowska/doodle/doodle/preclinical_dosimetry/phantomdata
# These organs from the biodi are not modelled in the phantom
# ['Fat', 'Muscle', 'Seminals', 'Tail', 'Tumor']
#
# These organs modelled in the phantom were not included in the biodistribution.
# ['Breasts', 'Esophagus', 'Eyes', 'Gallbladder', 'Ovaries', 'Prostate', 'Salivary Glands', 'Thymus', 'Thyroid', 'Uterus']
#                  Female   Male
# Organ
# Adrenals             13     14
# Bladder              40     50
# Body              60000  73000
# Bone Surfaces       120    120
# Brain              1300   1450
# Breasts             500     25
# Esophagus            35     40
# Eyes                 15     15
# Gallbladder           8     10
# Heart               250    330
# Heart Contents      370    510
# Kidneys             275    310
# Left Colon          145    150
# Liver              1400   1800
# Lungs               950   1200
# Ovaries              11      0
# Pancreas            120    140
# Prostate              0     17
# Rectum               70     70
# Red Marrow          900   1170
# Right Colon         145    150
# Salivary Glands      70     85
# Small Intestine     600    650
# Spleen              130    150
# Stomach             140    150
# Testes                0     35
# Thymus               20     25
# Thyroid              17     20
# Uterus               80      0
# Remainder Body    53032  64551

# %%
human.remainder_body_uptake()
# Out:
# At this point we are ignoring the tumor
# AdultHuman
# Disintegrations
#
#
# Literature Mass (g)
#
#            Female     Male
# Fat       16989.0  15169.4
# Muscle    17500.0  29000.0
# Seminals      0.0      6.4
#                  Female   Male
# Organ
# Adrenals             13     14
# Bladder              40     50
# Body              60000  73000
# Bone Surfaces       120    120
# Brain              1300   1450
# Breasts             500     25
# Esophagus            35     40
# Eyes                 15     15
# Gallbladder           8     10
# Heart               250    330
# Heart Contents      370    510
# Kidneys             275    310
# Left Colon          145    150
# Liver              1400   1800
# Lungs               950   1200
# Ovaries              11      0
# Pancreas            120    140
# Prostate              0     17
# Rectum               70     70
# Red Marrow          900   1170
# Right Colon         145    150
# Salivary Glands      70     85
# Small Intestine     600    650
# Spleen              130    150
# Stomach             140    150
# Testes                0     35
# Thymus               20     25
# Thyroid              17     20
# Uterus               80      0
# Remainder Body    53032  64551

# %%
human.disintegrations
# Out:
#                    %ID/g*h %ID*h Female  %ID*h Male
# Adrenals          0.694118      9.02353    9.717647
# Bladder          14.359011   574.360438  717.950548
# Bone Surfaces     0.023163     2.779564    2.779564
# Brain             0.005583     7.258293    8.095788
# Heart              0.12847    32.117555   42.395172
# Heart Contents    0.018836     6.969349      9.6064
# Kidneys           1.054705   290.043989  326.958679
# Left Colon        0.378524    54.885976   56.778595
# Liver             0.107563    150.58821  193.613413
# Lungs             0.128378   121.958737  154.053142
# Pancreas          2.135195    256.22338  298.927276
# Rectum            0.378524    26.496678   26.496678
# Red Marrow        0.006404      5.76384    7.492992
# Right Colon       0.378524    54.885976   56.778595
# Small Intestine   0.221358   132.814685  143.882575
# Spleen            0.145355    18.896176   21.803281
# Stomach           0.046307     6.482969    6.946038
# Testes            0.029278          0.0     1.02472
# Remainder Body         NaN   161.150263  215.983986

# %% [markdown]
# ### M2: Extrapolation of TIAC_H from TIAC_A applying a relative mass scaling factor (rMSF)

# %%
human.interspecies_conversion()

# %%
human.disintegrations
# Out:
#                    %ID/g*h %ID*h Female %ID*h Male
# Adrenals          0.694118      0.00376   0.003328
# Bladder          14.359011     0.239317   0.245873
# Bone Surfaces     0.023163     0.001158   0.000952
# Brain             0.005583     0.003024   0.002773
# Heart              0.12847     0.013382   0.014519
# Heart Contents    0.018836     0.002904    0.00329
# Kidneys           1.054705     0.120852   0.111972
# Left Colon        0.378524     0.022869   0.019445
# Liver             0.107563     0.062745   0.066306
# Lungs             0.128378     0.050816   0.052758
# Pancreas          2.135195      0.10676   0.102372
# Rectum            0.378524      0.01104   0.009074
# Red Marrow        0.006404     0.002402   0.002566
# Right Colon       0.378524     0.022869   0.019445
# Small Intestine   0.221358     0.055339   0.049275
# Spleen            0.145355     0.007873   0.007467
# Stomach           0.046307     0.002701   0.002379
# Testes            0.029278          0.0   0.000351
# Remainder Body         NaN     0.067146   0.073967

# %%
human.create_humancase(savefile=True,dirname=dirname)
# Out:
# The case file Male.cas has been saved in
# /mnt/y/Sara/Preclinical_dosimetry/PC3_17-01-2023_Lu177_GRPRtargeting_NRG_LeiWang-LW01110_updated

# %%
human.create_humancase(savefile=True,dirname=dirname)
# Out:
# The case file Male.cas has been saved in
# /mnt/y/Sara/Preclinical_dosimetry/PC3_17-01-2023_Lu177_GRPRtargeting_NRG_LeiWang-LW01110_updated
