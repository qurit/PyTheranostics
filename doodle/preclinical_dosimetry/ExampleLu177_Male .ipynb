# %%
date='--2023' 
isotope='Ga68'
tracer=''
cell_line=''
mouse_type='Male'
biodi_author='Shreya'
biodi_file = '/mnt/c/Users/skurkowska/Desktop/myszki/Shreya/Ga68_Males.csv'

# %%
import pandas as pd
import numpy as np
from numpy import exp,log

import os

from biodose import BioDose
from interspecies_extrapolation import Human_Extrapolation

# This allows external modification of .py and automatic module reload:
# %load_ext autoreload
# %autoreload 2
# To generate the plots within the notebook
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
Isotope = 'Ga-68'
half_life = 68 / 60 #hours

# %%
t = np.array([0.25,0.50,1,3])  #hours

# %%
mouse=BioDose(isotope=Isotope,half_life=half_life,phantom='Mouse25g',sex='Male',timepoints=t)

# %%
mouse.read_biodi(biodi_file)
mouse.biodi.dropna(inplace=True)

mouse.biodi
# Out:
# Reading biodistribution information from the file: /mnt/c/Users/skurkowska/Desktop/myszki/Shreya/Ga68_Males.csv
# Raw biodi (all data at injection time) available in self.raw_biodi
# Decay factors for this isotope at given times are
#  [0.85822 0.73653 0.54248 0.15965]
# Decayed biodistribution stored in self.biodi
#                                         %ID/g                      \
#                          0.25_%inj_activity/g 0.5_%inj_activity/g
# Organ
# ADRENALS                              3.27669             1.68750
# BLOOD                                 4.61541             2.22994
# BRAIN                                 0.10747             0.05305
# COLON                                 0.75613             0.39530
# FAT                                   0.27784             0.17861
# GALLBLADDER                           2.15825             1.20054
# HEART                                 1.24895             0.61601
# KIDNEYS                               7.54599             4.21737
# LARGE INTESTINE                       0.75827             0.41794
# LIVER                                 1.37344             0.74401
# LUNGS                                 3.23049             1.59243
# MUSCLE                                0.96776             0.56591
# PANCREAS                              1.13019             0.67143
# PROSTATE                              2.14508             0.78550
# RED MARROW                            1.38092             0.44827
# SALIVARY GLANDS                       4.57869             2.33220
# SEMINALS                              0.36776             0.31481
# SKELETON                              2.43838             1.38774
# SKIN                                  2.50111             1.53112
# SMALL INTESTINE                       1.04888             0.65913
# SPLEEN                                1.06727             0.53845
# STOMACH                               0.57833             0.24596
# TAIL                                  3.14644             1.90146
# TESTIS                                0.55713             0.37093
# THYMUS                                1.48963             0.64289
# URINARY BLADDER CONTENTS            124.98077           148.76164
#
#                                                                    sigma  \
#                          1_%inj_activity/g 180_%inj_activity/g   0.25_sd
# Organ
# ADRENALS                           0.84761             0.09842   1.85717
# BLOOD                              1.19167             0.06908   0.33749
# BRAIN                              0.03013             0.00303   0.01318
# COLON                              0.20423             0.26024   0.12534
# FAT                                0.08556             0.00650   0.03455
# GALLBLADDER                        1.40701             0.14748   1.38578
# HEART                              0.33106             0.02647   0.06696
# KIDNEYS                            3.29786             0.47381   0.72933
# LARGE INTESTINE                    0.18829             0.34087   0.10690
# LIVER                              0.48160             0.05879   0.07333
# LUNGS                              0.94766             0.07047   0.26982
# MUSCLE                             0.24780             0.01888   0.25844
# PANCREAS                           0.31904             0.02968   0.07956
# PROSTATE                           0.24622             0.03899   1.69010
# RED MARROW                         0.91431             0.06166   0.38994
# SALIVARY GLANDS                    1.15508             0.08022   0.89865
# SEMINALS                           0.11001             0.01319   0.07267
# SKELETON                           0.75418             0.06425   0.57445
# SKIN                               0.97483             0.06594   0.26377
# SMALL INTESTINE                    0.82728             0.08981   0.06170
# SPLEEN                             0.30097             0.03302   0.06724
# STOMACH                            0.12067             0.02180   0.07661
# TAIL                               1.31885             0.10575   0.41668
# TESTIS                             0.25119             0.02175   0.02805
# THYMUS                             0.39390             0.02091   0.14368
# URINARY BLADDER CONTENTS         217.23075            18.24112  36.50121
#
#
#                             0.5_sd      1_sd    180_sd
# Organ
# ADRENALS                   0.67934   0.30042   0.14086
# BLOOD                      0.24013   0.11940   0.02889
# BRAIN                      0.00817   0.00239   0.00225
# COLON                      0.12602   0.06670   0.07453
# FAT                        0.03799   0.00772   0.00163
# GALLBLADDER                0.44192   1.01712   0.17879
# HEART                      0.08894   0.05058   0.00271
# KIDNEYS                    0.20595   0.26516   0.03353
# LARGE INTESTINE            0.06781   0.02406   0.20711
# LIVER                      0.06239   0.04931   0.00565
# LUNGS                      0.23812   0.14703   0.01038
# MUSCLE                     0.19851   0.02544   0.00495
# PANCREAS                   0.07291   0.02878   0.00449
# PROSTATE                   0.42885   0.04281   0.03205
# RED MARROW                 0.41797   0.31000   0.07206
# SALIVARY GLANDS            0.50659   0.15218   0.03735
# SEMINALS                   0.18349   0.01923   0.01526
# SKELETON                   0.13867   0.19367   0.01508
# SKIN                       0.16548   0.09990   0.00530
# SMALL INTESTINE            0.08926   0.04944   0.03970
# SPLEEN                     0.05959   0.03110   0.00840
# STOMACH                    0.05930   0.03623   0.01400
# TAIL                       0.20138   0.13452   0.01589
# TESTIS                     0.04258   0.04300   0.00255
# THYMUS                     0.14805   0.07717   0.02386
# URINARY BLADDER CONTENTS  43.17252  86.39278  13.51883

# %%
mouse.curve_fits()
# Out:
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/doodle/doodle/plots/plots.py:37: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(1, 3, figsize=(10,4))
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /home/skurkowska/.local/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# Error in callback <function flush_figures at 0x7f7b05547400> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~/.local/lib/python3.10/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py:2346, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
# -> 2346         bbox_inches = self.figure.get_tightbbox(
#    2347             renderer, bbox_extra_artists=bbox_extra_artists)
#    2348         if pad_inches is None:
#    2349             pad_inches = rcParams['savefig.pad_inches']
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/figure.py:1785, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1781 if ax.get_visible():
#    1782     # some axes don't take the bbox_extra_artists kwarg so we
#    1783     # need this conditional....
#    1784     try:
# -> 1785         bbox = ax.get_tightbbox(
#    1786             renderer, bbox_extra_artists=bbox_extra_artists)
#    1787     except TypeError:
#    1788         bbox = ax.get_tightbbox(renderer)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:4385, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4383 for axis in self._axis_map.values():
#    4384     if self.axison and axis.get_visible():
# -> 4385         ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#    4386         if ba:
#    4387             bb.append(ba)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:1415, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1409 """
#    1410 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1411 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1412 when encountering third-party subclasses that do not support it.
#    1413 """
#    1414 try:
# -> 1415     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1416 except TypeError:
#    1417     return obj.get_tightbbox(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:1328, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1325 self._update_label_position(renderer)
#    1327 # go back to just this axis's tick labels
# -> 1328 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1330 self._update_offset_text_position(tlb1, tlb2)
#    1331 self.offsetText.set_text(self.major.formatter.get_offset())
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:1304, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1302 if renderer is None:
#    1303     renderer = self.figure._get_renderer()
# -> 1304 return ([tick.label1.get_window_extent(renderer)
#    1305          for tick in ticks if tick.label1.get_visible()],
#    1306         [tick.label2.get_window_extent(renderer)
#    1307          for tick in ticks if tick.label2.get_visible()])
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:1304, in <listcomp>(.0)
#    1302 if renderer is None:
#    1303     renderer = self.figure._get_renderer()
# -> 1304 return ([tick.label1.get_window_extent(renderer)
#    1305          for tick in ticks if tick.label1.get_visible()],
#    1306         [tick.label2.get_window_extent(renderer)
#    1307          for tick in ticks if tick.label2.get_visible()])
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/text.py:946, in Text.get_window_extent(self, renderer, dpi)
#     944 if self.get_text() == '':
#     945     with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 946         tx, ty = self._get_xy_display()
#     947         return Bbox.from_bounds(tx, ty, 0, 0)
#     949 if renderer is not None:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/text.py:275, in Text._get_xy_display(self)
#     271 """
#     272 Get the (possibly unit converted) transformed x, y in display coords.
#     273 """
#     274 x, y = self.get_unitless_position()
# --> 275 return self.get_transform().transform((x, y))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/transforms.py:1493, in Transform.transform(self, values)
#    1476 """
#    1477 Apply this transformation on the given array of *values*.
#    1478
#    (...)
#    1489     shape (N x :attr:`output_dims`), depending on the input.
#    1490 """
#    1491 # Ensure that values is a 2d array (but remember whether
#    1492 # we started with a 1d or 2d array).
# -> 1493 values = np.asanyarray(values)
#    1494 ndim = values.ndim
#    1495 values = values.reshape((-1, self.input_dims))
#
# KeyboardInterrupt:

# %%
mouse.area
# Out:
#                          Mono-Exponential Bi-Exponential  \
# Adrenals                         2.571058       3.420862
# Blood                            3.516951   64800.861117
# Brain                            0.084193    7000.340174
# Colon                            0.616839       1.094493
# Fat                              0.255393       0.274996
# Gallbladder                      3.155519       2.379785
# Heart                            0.965582   33795.981954
# Kidneys                          7.748447       7.911109
# Large intestine                  0.628059       0.835125
# Liver                            1.214715   16196.485095
# Lungs                            2.557647   41762.805685
# Muscle                           0.804953       0.901428
# Pancreas                         0.970925       1.117242
# Prostate                         1.451658       1.827979
# Red Marrow                       1.741962       1.596398
# Salivary glands                  3.555415       5.476188
# Seminal vesicles                 0.396682       0.376279
# Skeleton                         2.105053  103482.827725
# Skin                             2.471662       2.517595
# Small intestine                  1.890694        1.93145
# Spleen                           0.845915       1.542021
# Stomach                          0.408498       0.611508
# Tail                             3.225923       3.252829
# Testis                           0.630213       0.627052
# Thymus                           1.088626   15617.477541
# Urinary Bladder Contents       345.241706     257.773099
#
#                          Bi-Exponential_uptake Tri-Exponential  \
# Adrenals                                   NaN             NaN
# Blood                                      NaN             NaN
# Brain                                      NaN             NaN
# Colon                                      NaN             NaN
# Fat                                        NaN             NaN
# Gallbladder                                NaN             NaN
# Heart                                      NaN             NaN
# Kidneys                                    NaN             NaN
# Large intestine                            NaN             NaN
# Liver                                      NaN             NaN
# Lungs                                      NaN             NaN
# Muscle                                     NaN             NaN
# Pancreas                                   NaN             NaN
# Prostate                                   NaN             NaN
# Red Marrow                                 NaN             NaN
# Salivary glands                            NaN             NaN
# Seminal vesicles                           NaN             NaN
# Skeleton                                   NaN             NaN
# Skin                                       NaN             NaN
# Small intestine                            NaN             NaN
# Spleen                                     NaN             NaN
# Stomach                                    NaN             NaN
# Tail                                       NaN             NaN
# Testis                                     NaN             NaN
# Thymus                                     NaN             NaN
# Urinary Bladder Contents                   NaN             NaN
#
#                          Perctage_diff - mono vs bi washout  \
# Adrenals                                          33.052695
# Blood                                        1842429.800597
# Brain                                        8314487.599962
# Colon                                             77.435653
# Fat                                                7.675586
# Gallbladder                                       24.583396
# Heart                                        3499964.722908
# Kidneys                                            2.099287
# Large intestine                                   32.969228
# Liver                                        1333256.962356
# Lungs                                        1632760.286028
# Muscle                                            11.985198
# Pancreas                                          15.069869
# Prostate                                          25.923523
# Red Marrow                                         8.356319
# Salivary glands                                   54.023851
# Seminal vesicles                                   5.143361
# Skeleton                                     4915825.805106
# Skin                                                1.85837
# Small intestine                                    2.155618
# Spleen                                            82.290426
# Stomach                                           49.696799
# Tail                                               0.834047
# Testis                                             0.501634
# Thymus                                       1434504.386393
# Urinary Bladder Contents                          25.335469
#
#                          Perctage_diff - bi vs tri uptake washout
# Adrenals                                                      NaN
# Blood                                                         NaN
# Brain                                                         NaN
# Colon                                                         NaN
# Fat                                                           NaN
# Gallbladder                                                   NaN
# Heart                                                         NaN
# Kidneys                                                       NaN
# Large intestine                                               NaN
# Liver                                                         NaN
# Lungs                                                         NaN
# Muscle                                                        NaN
# Pancreas                                                      NaN
# Prostate                                                      NaN
# Red Marrow                                                    NaN
# Salivary glands                                               NaN
# Seminal vesicles                                              NaN
# Skeleton                                                      NaN
# Skin                                                          NaN
# Small intestine                                               NaN
# Spleen                                                        NaN
# Stomach                                                       NaN
# Tail                                                          NaN
# Testis                                                        NaN
# Thymus                                                        NaN
# Urinary Bladder Contents                                      NaN

# %%
mouse.curve_fits(organlist=['Gallbladder'],uptake=True,append_zero=True)

# %%
mouse.area
# Out:
#                          Mono-Exponential Bi-Exponential  \
# Adrenals                         2.571058       3.420862
# Blood                            3.516951   64800.861117
# Brain                            0.084193    7000.340174
# Colon                            0.616839       1.094493
# Fat                              0.255393       0.274996
# Gallbladder                      3.155519       2.379785
# Heart                            0.965582   33795.981954
# Kidneys                          7.748447       7.911109
# Large intestine                  0.628059       0.835125
# Liver                            1.214715   16196.485095
# Lungs                            2.557647   41762.805685
# Muscle                           0.804953       0.901428
# Pancreas                         0.970925       1.117242
# Prostate                         1.451658       1.827979
# Red Marrow                       1.741962       1.596398
# Salivary glands                  3.555415       5.476188
# Seminal vesicles                 0.396682       0.376279
# Skeleton                         2.105053  103482.827725
# Skin                             2.471662       2.517595
# Small intestine                  1.890694        1.93145
# Spleen                           0.845915       1.542021
# Stomach                          0.408498       0.611508
# Tail                             3.225923       3.252829
# Testis                           0.630213       0.627052
# Thymus                           1.088626   15617.477541
# Urinary Bladder Contents       345.241706     257.773099
#
#                          Bi-Exponential_uptake Tri-Exponential  \
# Adrenals                                   NaN             NaN
# Blood                                      NaN             NaN
# Brain                                      NaN             NaN
# Colon                                      NaN             NaN
# Fat                                        NaN             NaN
# Gallbladder                           2.355198             NaN
# Heart                                      NaN             NaN
# Kidneys                                    NaN             NaN
# Large intestine                            NaN             NaN
# Liver                                      NaN             NaN
# Lungs                                      NaN             NaN
# Muscle                                     NaN             NaN
# Pancreas                                   NaN             NaN
# Prostate                                   NaN             NaN
# Red Marrow                                 NaN             NaN
# Salivary glands                            NaN             NaN
# Seminal vesicles                           NaN             NaN
# Skeleton                                   NaN             NaN
# Skin                                       NaN             NaN
# Small intestine                            NaN             NaN
# Spleen                                     NaN             NaN
# Stomach                                    NaN             NaN
# Tail                                       NaN             NaN
# Testis                                     NaN             NaN
# Thymus                                     NaN             NaN
# Urinary Bladder Contents                   NaN             NaN
#
#                          Perctage_diff - mono vs bi washout  \
# Adrenals                                          33.052695
# Blood                                        1842429.800597
# Brain                                        8314487.599962
# Colon                                             77.435653
# Fat                                                7.675586
# Gallbladder                                       24.583396
# Heart                                        3499964.722908
# Kidneys                                            2.099287
# Large intestine                                   32.969228
# Liver                                        1333256.962356
# Lungs                                        1632760.286028
# Muscle                                            11.985198
# Pancreas                                          15.069869
# Prostate                                          25.923523
# Red Marrow                                         8.356319
# Salivary glands                                   54.023851
# Seminal vesicles                                   5.143361
# Skeleton                                     4915825.805106
# Skin                                                1.85837
# Small intestine                                    2.155618
# Spleen                                            82.290426
# Stomach                                           49.696799
# Tail                                               0.834047
# Testis                                             0.501634
# Thymus                                       1434504.386393
# Urinary Bladder Contents                          25.335469
#
#                          Perctage_diff - bi vs tri uptake washout
# Adrenals                                                      NaN
# Blood                                                         NaN
# Brain                                                         NaN
# Colon                                                         NaN
# Fat                                                           NaN
# Gallbladder                                                   NaN
# Heart                                                         NaN
# Kidneys                                                       NaN
# Large intestine                                               NaN
# Liver                                                         NaN
# Lungs                                                         NaN
# Muscle                                                        NaN
# Pancreas                                                      NaN
# Prostate                                                      NaN
# Red Marrow                                                    NaN
# Salivary glands                                               NaN
# Seminal vesicles                                              NaN
# Skeleton                                                      NaN
# Skin                                                          NaN
# Small intestine                                               NaN
# Spleen                                                        NaN
# Stomach                                                       NaN
# Tail                                                          NaN
# Testis                                                        NaN
# Thymus                                                        NaN
# Urinary Bladder Contents                                      NaN

# %%
fit_accepted={'Adrenals':2,
              'Blood':2,
              'Brain':2,
              'Colon':2,
              'Fat':2,
              'Gallbladder':3,
              'Heart':2,
              'Kidneys':2,
              'Large Intestine':2,
              'Liver':2,
              'Lungs':2,
              'Muscle':2,
              'Ovaries':2,
              'Pancreas':2,
              'Red Marrow':2,
              'Salivary Glands':2,
              'Skeleton':2,
              'Skin':2,
              'Small Intestine':2,
              'Spleen':2,
              'Stomach':2,
              'Tail':2,
              'Thymus':2,
              'Thyroid':2,
              'Urinary Bladder Contents': 2,
              'Uterus':2,                           
             }

# %%
mouse.num_decays(fit_accepted)
mouse.disintegrations
# Out:
#                                 %ID/g*h
# Organ
# Adrenals                       3.420862
# Blood                      64800.861117
# Brain                       7000.340174
# Colon                          1.094493
# Fat                            0.274996
# Gallbladder                    2.355198
# Heart                      33795.981954
# Kidneys                        7.911109
# Large intestine                     NaN
# Liver                      16196.485095
# Lungs                      41762.805685
# Muscle                         0.901428
# Pancreas                       1.117242
# Prostate                            NaN
# Red Marrow                     1.596398
# Salivary glands                     NaN
# Seminal vesicles                    NaN
# Skeleton                  103482.827725
# Skin                           2.517595
# Small intestine                     NaN
# Spleen                         1.542021
# Stomach                        0.611508
# Tail                           3.252829
# Testis                              NaN
# Thymus                     15617.477541
# Urinary Bladder Contents     257.773099
# Remainder Body                      NaN

# %%
mouse.phantom_data()
mouse.phantom_mass
# Out:
# /home/skurkowska/doodle/doodle/preclinical_dosimetry/phantomdata
# These organs from the biodi are not modelled in the phantom
# ['Adrenals', 'Blood', 'Colon', 'Fat', 'Gallbladder', 'Large intestine', 'Muscle', 'Prostate', 'Red Marrow', 'Salivary glands', 'Seminal vesicles', 'Skin', 'Small intestine', 'Tail', 'Testis', 'Thymus', 'Urinary Bladder Contents']
#
# These organs modelled in the phantom were not included in the biodistribution.
# ['Bladder', 'Large Intestine', 'Small Intestine', 'Testes', 'Thyroid']
#                     25g     30g     35g
# Organ
# Bladder           0.060   0.075   0.088
# Body             24.110  29.800  35.270
# Brain             0.466   0.568   0.666
# Heart             0.235   0.291   0.342
# Kidneys           0.302   0.374   0.432
# Large Intestine   0.583   0.709   0.830
# Liver             1.740   2.150   2.570
# Lungs             0.087   0.107   0.131
# Pancreas          0.305   0.378   0.450
# Skeleton          2.180   2.610   3.010
# Small Intestine   1.740   2.120   2.490
# Spleen            0.111   0.136   0.157
# Stomach           0.055   0.069   0.082
# Testes            0.160   0.197   0.228
# Thyroid           0.014   0.016   0.020
# Remainder Body   18.629  23.117  27.430

# %%
mouse.remainder_body_uptake()
# Out:
# At this point we are ignoring the tumor
# Mouse25g
# Disintegrations
#
#
# Literature Mass (g)
#
#                   25g        30g        35g
# Organ
# Adrenals     0.010200   0.010200   0.010200
# Blood        2.400000   2.400000   2.400000
# Fat          6.500000   7.800000   9.100000
# Gallbladder  0.011000   0.011000   0.011000
# Muscle       7.088755  10.276755  13.289755
# Skin         2.010000   2.010000   2.010000
# Thymus       0.051000   0.051000   0.051000
#                     25g     30g     35g
# Organ
# Bladder           0.060   0.075   0.088
# Body             24.110  29.800  35.270
# Brain             0.466   0.568   0.666
# Heart             0.235   0.291   0.342
# Kidneys           0.302   0.374   0.432
# Large Intestine   0.583   0.709   0.830
# Liver             1.740   2.150   2.570
# Lungs             0.087   0.107   0.131
# Pancreas          0.305   0.378   0.450
# Skeleton          2.180   2.610   3.010
# Small Intestine   1.740   2.120   2.490
# Spleen            0.111   0.136   0.157
# Stomach           0.055   0.069   0.082
# Testes            0.160   0.197   0.228
# Thyroid           0.014   0.016   0.020
# Remainder Body   18.629  23.117  27.430

# %%
mouse.disintegrations
# Out:
#                     %ID/g*h        %ID*h
# Organ
# Brain             70.003402    32.621585
# Heart             337.95982    79.420558
# Kidneys            0.079111     0.023892
# Liver            161.964851   281.818841
# Lungs            417.628057    36.333641
# Pancreas           0.011172     0.003408
# Skeleton        1034.828277  2255.925644
# Spleen              0.01542     0.001712
# Stomach            0.006115     0.000336
# Remainder Body          NaN  1563.318567

# %%
dirname='/home/skurkowska/pydose/pydose/Results/{}_{}_{}_{}_{}_{}_updated'.format(cell_line,date,isotope,tracer,mouse_type,biodi_author)
dirname
# Out:
# '/home/skurkowska/pydose/pydose/Results/_--2023_Ga68__Male_Shreya_updated'

# %%
mouse.create_mouse25case(savefile=True,dirname=dirname)
# Out:
# The case file mouse25g.cas has been saved in
# /home/skurkowska/pydose/pydose/Results/_--2023_Ga68__Male_Shreya_updated

# %%
mouse.biodi
# Out:
#                                         %ID/g                      \
#                          0.25_%inj_activity/g 0.5_%inj_activity/g
# Organ
# Adrenals                              3.27669             1.68750
# Blood                                 4.61541             2.22994
# Brain                                 0.10747             0.05305
# Colon                                 0.75613             0.39530
# Fat                                   0.27784             0.17861
# Gallbladder                           2.15825             1.20054
# Heart                                 1.24895             0.61601
# Kidneys                               7.54599             4.21737
# Large intestine                       0.75827             0.41794
# Liver                                 1.37344             0.74401
# Lungs                                 3.23049             1.59243
# Muscle                                0.96776             0.56591
# Pancreas                              1.13019             0.67143
# Prostate                              2.14508             0.78550
# Red Marrow                            1.38092             0.44827
# Salivary glands                       4.57869             2.33220
# Seminal vesicles                      0.36776             0.31481
# Skeleton                              2.43838             1.38774
# Skin                                  2.50111             1.53112
# Small intestine                       1.04888             0.65913
# Spleen                                1.06727             0.53845
# Stomach                               0.57833             0.24596
# Tail                                  3.14644             1.90146
# Testis                                0.55713             0.37093
# Thymus                                1.48963             0.64289
# Urinary Bladder Contents            124.98077           148.76164
#
#                                                                    sigma  \
#                          1_%inj_activity/g 180_%inj_activity/g   0.25_sd
# Organ
# Adrenals                           0.84761             0.09842   1.85717
# Blood                              1.19167             0.06908   0.33749
# Brain                              0.03013             0.00303   0.01318
# Colon                              0.20423             0.26024   0.12534
# Fat                                0.08556             0.00650   0.03455
# Gallbladder                        1.40701             0.14748   1.38578
# Heart                              0.33106             0.02647   0.06696
# Kidneys                            3.29786             0.47381   0.72933
# Large intestine                    0.18829             0.34087   0.10690
# Liver                              0.48160             0.05879   0.07333
# Lungs                              0.94766             0.07047   0.26982
# Muscle                             0.24780             0.01888   0.25844
# Pancreas                           0.31904             0.02968   0.07956
# Prostate                           0.24622             0.03899   1.69010
# Red Marrow                         0.91431             0.06166   0.38994
# Salivary glands                    1.15508             0.08022   0.89865
# Seminal vesicles                   0.11001             0.01319   0.07267
# Skeleton                           0.75418             0.06425   0.57445
# Skin                               0.97483             0.06594   0.26377
# Small intestine                    0.82728             0.08981   0.06170
# Spleen                             0.30097             0.03302   0.06724
# Stomach                            0.12067             0.02180   0.07661
# Tail                               1.31885             0.10575   0.41668
# Testis                             0.25119             0.02175   0.02805
# Thymus                             0.39390             0.02091   0.14368
# Urinary Bladder Contents         217.23075            18.24112  36.50121
#
#
#                             0.5_sd      1_sd    180_sd
# Organ
# Adrenals                   0.67934   0.30042   0.14086
# Blood                      0.24013   0.11940   0.02889
# Brain                      0.00817   0.00239   0.00225
# Colon                      0.12602   0.06670   0.07453
# Fat                        0.03799   0.00772   0.00163
# Gallbladder                0.44192   1.01712   0.17879
# Heart                      0.08894   0.05058   0.00271
# Kidneys                    0.20595   0.26516   0.03353
# Large intestine            0.06781   0.02406   0.20711
# Liver                      0.06239   0.04931   0.00565
# Lungs                      0.23812   0.14703   0.01038
# Muscle                     0.19851   0.02544   0.00495
# Pancreas                   0.07291   0.02878   0.00449
# Prostate                   0.42885   0.04281   0.03205
# Red Marrow                 0.41797   0.31000   0.07206
# Salivary glands            0.50659   0.15218   0.03735
# Seminal vesicles           0.18349   0.01923   0.01526
# Skeleton                   0.13867   0.19367   0.01508
# Skin                       0.16548   0.09990   0.00530
# Small intestine            0.08926   0.04944   0.03970
# Spleen                     0.05959   0.03110   0.00840
# Stomach                    0.05930   0.03623   0.01400
# Tail                       0.20138   0.13452   0.01589
# Testis                     0.04258   0.04300   0.00255
# Thymus                     0.14805   0.07717   0.02386
# Urinary Bladder Contents  43.17252  86.39278  13.51883

# %%
human = mouse.humanize_biodi(small_intestine=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Large Intestine'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/skurkowska/doodle/doodle/preclinical_dosimetry/ShreyaGa68_Male.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/skurkowska/doodle/doodle/preclinical_dosimetry/ShreyaGa68_Male.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> human = mouse.humanize_biodi(small_intestine=False)
#
# File ~/doodle/doodle/preclinical_dosimetry/biodose.py:339, in BioDose.humanize_biodi(self, small_intestine)
#     335 human = deepcopy(self)
#     337 human.phantom='AdultHuman'
# --> 339 human.biodi.loc['Small Intestine'] = human.biodi.loc['Large Intestine']
#     340 human.biodi.sort_index(inplace=True)
#     342 human.rename_organ('Skeleton','Bone Surfaces')
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:4095, in NDFrame.xs(self, key, axis, level, drop_level)
#    4093             new_index = index[loc]
#    4094 else:
# -> 4095     loc = index.get_loc(key)
#    4097     if isinstance(loc, np.ndarray):
#    4098         if loc.dtype == np.bool_:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Large Intestine'

# %%
human.fit_accepted
# Out:
# {'Adrenals': 2,
#  'Heart Contents': 2,
#  'Red Marrow': 2,
#  'Brain': 2,
#  'Colon': 2,
#  'Fat': 2,
#  'Gallbladder': 3,
#  'Heart': 2,
#  'Kidneys': 2,
#  'Left Colon': 2,
#  'Right Colon': 2,
#  'Rectum': 2,
#  'Liver': 2,
#  'Lungs': 2,
#  'Muscle': 2,
#  'Ovaries': 2,
#  'Pancreas': 2,
#  'Salivary Glands': 2,
#  'Bone Surfaces': 2,
#  'Skin': 2,
#  'Small Intestine': 2,
#  'Spleen': 2,
#  'Stomach': 2,
#  'Tail': 2,
#  'Thymus': 2,
#  'Thyroid': 2,
#  'Urinary Bladder Contents': 2,
#  'Uterus': 2}

# %%
human.num_decays(human.fit_accepted)
human.disintegrations
# Out:
#                              %ID/g*h
# Adrenals                    2.128909
# Bone Surfaces               2.382744
# Brain                       0.100185
# Colon                       1.145264
# Fat                         0.428298
# Gallbladder                 2.945783
# Heart                       1.381848
# Heart Contents              4.734713
# Kidneys                      7.60625
# Left Colon                  0.931345
# Liver                       1.666988
# Lungs                       3.491882
# Muscle                      1.016312
# Ovaries                     2.699421
# Pancreas                    1.637849
# Rectum                      0.931345
# Red Marrow                  1.870512
# Right Colon                 0.931345
# Salivary Glands             3.054986
# Skin                        3.612813
# Small Intestine             1.708431
# Spleen                      1.118037
# Stomach                     0.700805
# Tail                        3.627879
# Thymus                      2.117713
# Thyroid                      2.34618
# Urinary Bladder Contents  600.180735
# Uterus                      4.519068
# Remainder Body                   NaN

# %%
human.phantom_data()
human.phantom_mass
# Out:
# /home/skurkowska/doodle/doodle/preclinical_dosimetry/phantomdata
# These organs from the biodi are not modelled in the phantom
# ['Colon', 'Fat', 'Muscle', 'Skin', 'Tail', 'Urinary Bladder Contents']
#
# These organs modelled in the phantom were not included in the biodistribution.
# ['Bladder', 'Breasts', 'Esophagus', 'Eyes', 'Prostate', 'Testes']
#                  Female   Male
# Organ
# Adrenals             13     14
# Bladder              40     50
# Body              60000  73000
# Bone Surfaces       120    120
# Brain              1300   1450
# Breasts             500     25
# Esophagus            35     40
# Eyes                 15     15
# Gallbladder           8     10
# Heart               250    330
# Heart Contents      370    510
# Kidneys             275    310
# Left Colon          145    150
# Liver              1400   1800
# Lungs               950   1200
# Ovaries              11      0
# Pancreas            120    140
# Prostate              0     17
# Rectum               70     70
# Red Marrow          900   1170
# Right Colon         145    150
# Salivary Glands      70     85
# Small Intestine     600    650
# Spleen              130    150
# Stomach             140    150
# Testes                0     35
# Thymus               20     25
# Thyroid              17     20
# Uterus               80      0
# Remainder Body    52866  64496

# %%
human.remainder_body_uptake()
# Out:
# At this point we are ignoring the tumor
# AdultHuman
# Disintegrations
#
#       Organ   Female     Male
# 0       Fat  16989.0  15169.4
# 1  Seminals      0.0      6.4
# 2    Muscle  17500.0  29000.0
# 3      Skin   9600.0  11680.0
# 4   Trachea      NaN      NaN
#
# Literature Mass (g)
#
#          Female     Male
# Fat     16989.0  15169.4
# Muscle  17500.0  29000.0
# Skin     9600.0  11680.0
#                  Female   Male
# Organ
# Adrenals             13     14
# Bladder              40     50
# Body              60000  73000
# Bone Surfaces       120    120
# Brain              1300   1450
# Breasts             500     25
# Esophagus            35     40
# Eyes                 15     15
# Gallbladder           8     10
# Heart               250    330
# Heart Contents      370    510
# Kidneys             275    310
# Left Colon          145    150
# Liver              1400   1800
# Lungs               950   1200
# Ovaries              11      0
# Pancreas            120    140
# Prostate              0     17
# Rectum               70     70
# Red Marrow          900   1170
# Right Colon         145    150
# Salivary Glands      70     85
# Small Intestine     600    650
# Spleen              130    150
# Stomach             140    150
# Testes                0     35
# Thymus               20     25
# Thyroid              17     20
# Uterus               80      0
# Remainder Body    52866  64496

# %%
human.disintegrations
# Out:
#                   %ID/g*h %ID*h Female  %ID*h Male
# Adrenals         0.021289     0.276758    0.298047
# Bone Surfaces    0.023827     2.859293    2.859293
# Brain            0.001002      1.30241    1.452689
# Gallbladder      0.029458     0.235663    0.294578
# Heart            0.013818      3.45462    4.560098
# Heart Contents   0.047347    17.518437   24.147035
# Kidneys          0.076062    20.917186   23.579374
# Left Colon       0.009313      1.35045    1.397017
# Liver             0.01667    23.337835   30.005788
# Lungs            0.034919    33.172875   41.902579
# Ovaries          0.026994     0.296936         0.0
# Pancreas         0.016378     1.965419    2.292989
# Rectum           0.009313     0.651941    0.651941
# Red Marrow       0.018705    16.834611   21.884994
# Right Colon      0.009313      1.35045    1.397017
# Salivary Glands   0.03055      2.13849    2.596738
# Small Intestine  0.017084    10.250586   11.104802
# Spleen            0.01118     1.453448    1.677056
# Stomach          0.007008     0.981127    1.051208
# Thymus           0.021177     0.423543    0.529428
# Thyroid          0.023462     0.398851    0.469236
# Uterus           0.045191     3.615254         0.0
# Remainder Body        NaN   597.448305  781.677427

# %% [markdown]
# ### M2: Extrapolation of TIAC_H from TIAC_A applying a relative mass scaling factor (rMSF)

# %%
human.interspecies_conversion()

# %%
human.disintegrations
# Out:
#                   %ID/g*h %ID*h Female %ID*h Male
# Adrenals         0.021289     0.000115   0.000102
# Bone Surfaces    0.023827     0.001191   0.000979
# Brain            0.001002     0.000543   0.000497
# Gallbladder      0.029458     0.000098   0.000101
# Heart            0.013818     0.001439   0.001562
# Heart Contents   0.047347     0.007299    0.00827
# Kidneys          0.076062     0.008715   0.008075
# Left Colon       0.009313     0.000563   0.000478
# Liver             0.01667     0.009724   0.010276
# Lungs            0.034919     0.013822    0.01435
# Ovaries          0.026994     0.000124        0.0
# Pancreas         0.016378     0.000819   0.000785
# Rectum           0.009313     0.000272   0.000223
# Red Marrow       0.018705     0.007014   0.007495
# Right Colon      0.009313     0.000563   0.000478
# Salivary Glands   0.03055     0.000891   0.000889
# Small Intestine  0.017084     0.004271   0.003803
# Spleen            0.01118     0.000606   0.000574
# Stomach          0.007008     0.000409    0.00036
# Thymus           0.021177     0.000176   0.000181
# Thyroid          0.023462     0.000166   0.000161
# Uterus           0.045191     0.001506        0.0
# Remainder Body        NaN     0.248937   0.267698

# %%
human.create_humancase(savefile=True,dirname=dirname)
# Out:
# The case file Female.cas has been saved in
# /home/skurkowska/pydose/pydose/Results/_--2023_Ga68___Shreya_updated
