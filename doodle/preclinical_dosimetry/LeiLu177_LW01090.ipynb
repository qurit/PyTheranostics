# %%
date='04-11-2022' 
isotope='Lu177'
tracer='GRPRtargeting'
cell_line='PC3'
mouse_type='NRG'
biodi_author='LeiWang-LW01090'
biodi_file = '/mnt/y/Sara/Preclinical_dosimetry/Lei/20221104_Lu177_LW01090_all time points.csv'

# %%
import pandas as pd
import numpy as np
from numpy import exp,log

import os

from biodose import BioDose

# This allows external modification of .py and automatic module reload:
# %load_ext autoreload
# %autoreload 2
# To generate the plots within the notebook
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
Isotope = 'Lu-177'
half_life = 159.528 #hours

# %%
t = np.array([1, 4, 24, 72, 120])  #hours

# %%
mouse=BioDose(isotope=Isotope,half_life=half_life,phantom='Mouse25g',sex='Male',timepoints=t)

# %%
mouse.read_biodi(biodi_file)
mouse.biodi.dropna(inplace=True)
mouse.biodi
# Out:
# Reading biodistribution information from the file: /mnt/y/Sara/Preclinical_dosimetry/Lei/20221104_Lu177_LW01090_all time points.csv
# Raw biodi (all data at injection time) available in self.raw_biodi
# Decay factors for this isotope at given times are
#  [0.99566 0.98277 0.90097 0.73137 0.59369]
# Decayed biodistribution stored in self.biodi
#                      %ID/g                                            sigma  \
#                    1_%ID/g   4_%ID/g 24_%ID/g 72_%ID/g 120_%ID/g       1_sd
# Organ
# Adrenals           0.60742   0.28198  0.15601  0.13223   0.07151    0.27757
# Bladder          362.35172  48.90588  1.12688  0.28069   0.07712  138.44313
# Blood              1.76340   0.83564  0.19299  0.05223   0.01752    0.14214
# Brain              0.04387   0.01963  0.00364  0.00195   0.00072    0.00317
# Fat                0.15220   0.05871  0.02600  0.01114   0.00661    0.03751
# Heart              0.44893   0.21078  0.08261  0.03926   0.02166    0.05752
# Kidneys            3.45702   3.04213  1.24418  0.44192   0.23062    0.28658
# Large Intestine    0.40898   0.41668  0.38256  0.07205   0.01744    0.23500
# Liver              0.66663   0.53196  0.26120  0.14872   0.09569    0.07063
# Lungs              2.19119   1.42668  0.22409  0.09191   0.04379    0.92529
# Muscle             0.21934   0.09693  0.03103  0.01489   0.00836    0.01461
# Pancreas           1.07547   0.20720  0.07350  0.02598   0.01160    0.21934
# Seminals           0.13542   0.05573  0.01957  0.02685   0.00693    0.01586
# Skeleton           0.11860   0.08472  0.06706  0.05144   0.04077    0.01876
# Small Intestine    0.59326   0.18712  0.08091  0.02127   0.00915    0.15628
# Spleen             0.31341   0.22505  0.14834  0.13463   0.08173    0.02867
# Stomach            0.31049   0.10800  0.24621  0.02034   0.01357    0.17237
# Tail               0.70860   0.38104  0.12955  0.09277   0.14010    0.11659
# Testes             0.44979   0.23030  0.11066  0.06185   0.04863    0.11270
# Tumor              8.67184   4.71490  1.59338  0.79795   0.39166    0.52471
#
#
#                      4_sd    24_sd    72_sd   120_sd
# Organ
# Adrenals          0.07055  0.01958  0.08726  0.04665
# Bladder          21.85348  0.51438  0.09845  0.02901
# Blood             0.03320  0.01486  0.00910  0.00341
# Brain             0.00410  0.00057  0.00120  0.00020
# Fat               0.00823  0.00801  0.00424  0.00304
# Heart             0.03339  0.00831  0.00811  0.00314
# Kidneys           0.34371  0.15812  0.05273  0.06591
# Large Intestine   0.09179  0.22611  0.05686  0.01095
# Liver             0.03778  0.01486  0.01733  0.03995
# Lungs             0.33500  0.02972  0.01058  0.01639
# Muscle            0.01852  0.00338  0.00184  0.00080
# Pancreas          0.01232  0.01440  0.00531  0.00262
# Seminals          0.00875  0.00456  0.03357  0.00285
# Skeleton          0.02515  0.01672  0.00807  0.00853
# Small Intestine   0.04896  0.02344  0.00197  0.00177
# Spleen            0.04111  0.02656  0.03891  0.03790
# Stomach           0.05280  0.14861  0.00165  0.01073
# Tail              0.07381  0.02845  0.03139  0.13372
# Testes            0.03580  0.01414  0.02949  0.01088
# Tumor             0.31746  0.24109  0.14152  0.13771

# %%
mouse.curve_fits()
# Out:
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# /home/skurkowska/doodle/doodle/plots/plots.py:37: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(1, 3, figsize=(10,4))
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere
# imhere

# %%
mouse.area
# Out:
#                 Mono-Exponential Bi-Exponential Bi-Exponential_uptake  \
# Adrenals                3.166387      26.424042                   NaN
# Bladder              1058.168784    1123.230044                   NaN
# Blood                   9.207673      19.721571                   NaN
# Brain                   0.215292       0.447623                   NaN
# Fat                     0.661246       0.664734                   NaN
# Heart                    2.34507       9.433624                   NaN
# Kidneys                89.959441     120.237812                   NaN
# Large Intestine        24.620204       17.41382                   NaN
# Liver                  23.528286      33.241395                   NaN
# Lungs                  19.853428      31.322317                   NaN
# Muscle                   1.06854       2.762738                   NaN
# Pancreas                3.392181       8.538317                   NaN
# Seminals                0.618754       2.770882                   NaN
# Skeleton               10.962462       14.73275                   NaN
# Small Intestine         2.267637       6.296961                   NaN
# Spleen                 23.316244      33.626663                   NaN
# Stomach                 1.266838       8.442004                   NaN
# Tail                    4.637431      29.654687                   NaN
# Testes                  2.771048      16.733187                   NaN
# Tumor                  58.606369     184.189864                   NaN
#
#                 Tri-Exponential Perctage_diff - mono vs bi washout  \
# Adrenals                    NaN                         734.517213
# Bladder                     NaN                           6.148477
# Blood                       NaN                          114.18628
# Brain                       NaN                         107.914498
# Fat                         NaN                           0.527517
# Heart                       NaN                         302.274783
# Kidneys                     NaN                          33.657803
# Large Intestine             NaN                          29.270204
# Liver                       NaN                          41.282691
# Lungs                       NaN                          57.767807
# Muscle                      NaN                         158.552489
# Pancreas                    NaN                         151.705788
# Seminals                    NaN                         347.816162
# Skeleton                    NaN                          34.392713
# Small Intestine             NaN                         177.688296
# Spleen                      NaN                          44.219895
# Stomach                     NaN                         566.384026
# Tail                        NaN                         539.463741
# Testes                      NaN                         503.857706
# Tumor                       NaN                         214.283017
#
#                 Perctage_diff - bi vs tri uptake washout
# Adrenals                                             NaN
# Bladder                                              NaN
# Blood                                                NaN
# Brain                                                NaN
# Fat                                                  NaN
# Heart                                                NaN
# Kidneys                                              NaN
# Large Intestine                                      NaN
# Liver                                                NaN
# Lungs                                                NaN
# Muscle                                               NaN
# Pancreas                                             NaN
# Seminals                                             NaN
# Skeleton                                             NaN
# Small Intestine                                      NaN
# Spleen                                               NaN
# Stomach                                              NaN
# Tail                                                 NaN
# Testes                                               NaN
# Tumor                                                NaN

# %%
mouse.curve_fits(organlist=['Large Intestine'],uptake=True,append_zero=True, uptakeguess=(10,0.01,-100,1))

# %%
mouse.area
# Out:
#                 Mono-Exponential Bi-Exponential Bi-Exponential_uptake  \
# Adrenals                3.166387      26.424042                   NaN
# Bladder              1058.168784    1123.230044                   NaN
# Blood                   9.207673      19.721571                   NaN
# Brain                   0.215292       0.447623                   NaN
# Fat                     0.661246       0.664734                   NaN
# Heart                    2.34507       9.433624                   NaN
# Kidneys                89.959441     120.237812                   NaN
# Large Intestine        24.620204       17.41382             21.444802
# Liver                  23.528286      33.241395                   NaN
# Lungs                  19.853428      31.322317                   NaN
# Muscle                   1.06854       2.762738                   NaN
# Pancreas                3.392181       8.538317                   NaN
# Seminals                0.618754       2.770882                   NaN
# Skeleton               10.962462       14.73275                   NaN
# Small Intestine         2.267637       6.296961                   NaN
# Spleen                 23.316244      33.626663                   NaN
# Stomach                 1.266838       8.442004                   NaN
# Tail                    4.637431      29.654687                   NaN
# Testes                  2.771048      16.733187                   NaN
# Tumor                  58.606369     184.189864                   NaN
#
#                 Tri-Exponential Perctage_diff - mono vs bi washout  \
# Adrenals                    NaN                         734.517213
# Bladder                     NaN                           6.148477
# Blood                       NaN                          114.18628
# Brain                       NaN                         107.914498
# Fat                         NaN                           0.527517
# Heart                       NaN                         302.274783
# Kidneys                     NaN                          33.657803
# Large Intestine             NaN                          29.270204
# Liver                       NaN                          41.282691
# Lungs                       NaN                          57.767807
# Muscle                      NaN                         158.552489
# Pancreas                    NaN                         151.705788
# Seminals                    NaN                         347.816162
# Skeleton                    NaN                          34.392713
# Small Intestine             NaN                         177.688296
# Spleen                      NaN                          44.219895
# Stomach                     NaN                         566.384026
# Tail                        NaN                         539.463741
# Testes                      NaN                         503.857706
# Tumor                       NaN                         214.283017
#
#                 Perctage_diff - bi vs tri uptake washout
# Adrenals                                             NaN
# Bladder                                              NaN
# Blood                                                NaN
# Brain                                                NaN
# Fat                                                  NaN
# Heart                                                NaN
# Kidneys                                              NaN
# Large Intestine                                      NaN
# Liver                                                NaN
# Lungs                                                NaN
# Muscle                                               NaN
# Pancreas                                             NaN
# Seminals                                             NaN
# Skeleton                                             NaN
# Small Intestine                                      NaN
# Spleen                                               NaN
# Stomach                                              NaN
# Tail                                                 NaN
# Testes                                               NaN
# Tumor                                                NaN

# %%
fit_accepted={'Adrenals':2,
              'Bladder':2,
              'Blood':2,
              'Brain':1,
              'Fat':2,
              'Heart':2,
              'Kidneys':2,
              'Large Intestine':3,
              'Liver':2,
              'Lungs':2,
              'Muscle':1,
              'Pancreas':2,
              'Seminals':2,
              'Skeleton':2,
              'Small Intestine':2,
              'Spleen':2,
              'Stomach':1,
              'Tail':2,
              'Testes':2,
              'Tumor':2,                       
             }

# %%
mouse.num_decays(fit_accepted)
mouse.disintegrations
# Out:
#                      %ID/g*h
# Organ
# Adrenals           26.424042
# Bladder          1123.230044
# Blood              19.721571
# Brain               0.215292
# Fat                 0.664734
# Heart               9.433624
# Kidneys           120.237812
# Large Intestine    21.444802
# Liver              33.241395
# Lungs              31.322317
# Muscle               1.06854
# Pancreas            8.538317
# Seminals            2.770882
# Skeleton            14.73275
# Small Intestine     6.296961
# Spleen             33.626663
# Stomach             1.266838
# Tail               29.654687
# Testes             16.733187
# Tumor             184.189864
# Remainder Body           NaN

# %%
mouse.phantom_data()
mouse.add_tumor_mass('Tumor',0.2925) 
mouse.phantom_mass
# Out:
# /home/skurkowska/doodle/doodle/preclinical_dosimetry/phantomdata
# These organs from the biodi are not modelled in the phantom
# ['Adrenals', 'Blood', 'Fat', 'Muscle', 'Seminals', 'Tail', 'Tumor']
#
# These organs modelled in the phantom were not included in the biodistribution.
# ['Thyroid']
#                      25g      30g      35g
# Organ
# Bladder           0.0600   0.0750   0.0880
# Body             24.1100  29.8000  35.2700
# Brain             0.4660   0.5680   0.6660
# Heart             0.2350   0.2910   0.3420
# Kidneys           0.3020   0.3740   0.4320
# Large Intestine   0.5830   0.7090   0.8300
# Liver             1.7400   2.1500   2.5700
# Lungs             0.0870   0.1070   0.1310
# Pancreas          0.3050   0.3780   0.4500
# Skeleton          2.1800   2.6100   3.0100
# Small Intestine   1.7400   2.1200   2.4900
# Spleen            0.1110   0.1360   0.1570
# Stomach           0.0550   0.0690   0.0820
# Testes            0.1600   0.1970   0.2280
# Thyroid           0.0140   0.0160   0.0200
# Remainder Body   16.0860  20.0160  23.7940
# Tumor             0.2925   0.2925   0.2925

# %%
mouse.remainder_body_uptake(tumor_name='Tumor')
# Out:
# At this point we are ignoring the tumor
# Mouse25g
# Disintegrations
#
#
# Literature Mass (g)
#
#                25g       30g       35g
# Organ
# Adrenals  0.010200  0.010200  0.010200
# Blood     2.400000  2.400000  2.400000
# Fat       6.500000  7.800000  9.100000
# Muscle    4.545755  7.175755  9.653755
# Seminals  0.173045  0.173045  0.173045
#                      25g      30g      35g
# Organ
# Bladder           0.0600   0.0750   0.0880
# Body             24.1100  29.8000  35.2700
# Brain             0.4660   0.5680   0.6660
# Heart             0.2350   0.2910   0.3420
# Kidneys           0.3020   0.3740   0.4320
# Large Intestine   0.5830   0.7090   0.8300
# Liver             1.7400   2.1500   2.5700
# Lungs             0.0870   0.1070   0.1310
# Pancreas          0.3050   0.3780   0.4500
# Skeleton          2.1800   2.6100   3.0100
# Small Intestine   1.7400   2.1200   2.4900
# Spleen            0.1110   0.1360   0.1570
# Stomach           0.0550   0.0690   0.0820
# Testes            0.1600   0.1970   0.2280
# Thyroid           0.0140   0.0160   0.0200
# Remainder Body   16.0860  20.0160  23.7940
# Tumor             0.2925   0.2925   0.2925

# %%
mouse.disintegrations
# Out:
#                   %ID/g*h     %ID*h
# Organ
# Bladder           11.2323  0.673938
# Brain            0.002153  0.001003
# Heart            0.094336  0.022169
# Kidneys          1.202378  0.363118
# Large Intestine  0.214448  0.125023
# Liver            0.332414    0.5784
# Lungs            0.313223   0.02725
# Pancreas         0.085383  0.026042
# Skeleton         0.147327  0.321174
# Small Intestine   0.06297  0.109567
# Spleen           0.336267  0.037326
# Stomach          0.012668  0.000697
# Testes           0.167332  0.026773
# Tumor            1.841899  0.538755
# Remainder Body        NaN  0.572589

# %%
mouse.tumor_sink_effect()
mouse.disintegrations
# Out:
# <class 'pandas.core.series.Series'>
#                   %ID/g*h     %ID*h
# Organ
# Bladder           11.2323  0.799789
# Brain            0.002153  0.001191
# Heart            0.094336  0.026309
# Kidneys          1.202378  0.430927
# Large Intestine  0.214448   0.14837
# Liver            0.332414   0.68641
# Lungs            0.313223  0.032339
# Pancreas         0.085383  0.030905
# Skeleton         0.147327   0.38115
# Small Intestine   0.06297  0.130028
# Spleen           0.336267  0.044296
# Stomach          0.012668  0.000827
# Testes           0.167332  0.031773
# Tumor            1.841899  0.538755
# Remainder Body        NaN  0.679514

# %%
dirname='/mnt/y/Sara/Preclinical_dosimetry/{}_{}_{}_{}_{}_{}_updated'.format(cell_line,date,isotope,tracer,mouse_type,biodi_author)
dirname
# Out:
# '/mnt/y/Sara/Preclinical_dosimetry/PC3_04-11-2022_Lu177_GRPRtargeting_NRG_LeiWang-LW01090_updated'

# %%
mouse.create_mouse25case(savefile=True,dirname=dirname)
# Out:
# The case file mouse25g.cas has been saved in
# /mnt/y/Sara/Preclinical_dosimetry/PC3_04-11-2022_Lu177_GRPRtargeting_NRG_LeiWang-LW01090_updated

# %%
mouse.biodi
# Out:
#                      %ID/g                                            sigma  \
#                    1_%ID/g   4_%ID/g 24_%ID/g 72_%ID/g 120_%ID/g       1_sd
# Organ
# Adrenals           0.60742   0.28198  0.15601  0.13223   0.07151    0.27757
# Bladder          362.35172  48.90588  1.12688  0.28069   0.07712  138.44313
# Blood              1.76340   0.83564  0.19299  0.05223   0.01752    0.14214
# Brain              0.04387   0.01963  0.00364  0.00195   0.00072    0.00317
# Fat                0.15220   0.05871  0.02600  0.01114   0.00661    0.03751
# Heart              0.44893   0.21078  0.08261  0.03926   0.02166    0.05752
# Kidneys            3.45702   3.04213  1.24418  0.44192   0.23062    0.28658
# Large Intestine    0.40898   0.41668  0.38256  0.07205   0.01744    0.23500
# Liver              0.66663   0.53196  0.26120  0.14872   0.09569    0.07063
# Lungs              2.19119   1.42668  0.22409  0.09191   0.04379    0.92529
# Muscle             0.21934   0.09693  0.03103  0.01489   0.00836    0.01461
# Pancreas           1.07547   0.20720  0.07350  0.02598   0.01160    0.21934
# Seminals           0.13542   0.05573  0.01957  0.02685   0.00693    0.01586
# Skeleton           0.11860   0.08472  0.06706  0.05144   0.04077    0.01876
# Small Intestine    0.59326   0.18712  0.08091  0.02127   0.00915    0.15628
# Spleen             0.31341   0.22505  0.14834  0.13463   0.08173    0.02867
# Stomach            0.31049   0.10800  0.24621  0.02034   0.01357    0.17237
# Tail               0.70860   0.38104  0.12955  0.09277   0.14010    0.11659
# Testes             0.44979   0.23030  0.11066  0.06185   0.04863    0.11270
# Tumor              8.67184   4.71490  1.59338  0.79795   0.39166    0.52471
#
#
#                      4_sd    24_sd    72_sd   120_sd
# Organ
# Adrenals          0.07055  0.01958  0.08726  0.04665
# Bladder          21.85348  0.51438  0.09845  0.02901
# Blood             0.03320  0.01486  0.00910  0.00341
# Brain             0.00410  0.00057  0.00120  0.00020
# Fat               0.00823  0.00801  0.00424  0.00304
# Heart             0.03339  0.00831  0.00811  0.00314
# Kidneys           0.34371  0.15812  0.05273  0.06591
# Large Intestine   0.09179  0.22611  0.05686  0.01095
# Liver             0.03778  0.01486  0.01733  0.03995
# Lungs             0.33500  0.02972  0.01058  0.01639
# Muscle            0.01852  0.00338  0.00184  0.00080
# Pancreas          0.01232  0.01440  0.00531  0.00262
# Seminals          0.00875  0.00456  0.03357  0.00285
# Skeleton          0.02515  0.01672  0.00807  0.00853
# Small Intestine   0.04896  0.02344  0.00197  0.00177
# Spleen            0.04111  0.02656  0.03891  0.03790
# Stomach           0.05280  0.14861  0.00165  0.01073
# Tail              0.07381  0.02845  0.03139  0.13372
# Testes            0.03580  0.01414  0.02949  0.01088
# Tumor             0.31746  0.24109  0.14152  0.13771

# %%
human = mouse.humanize_biodi(small_intestine=False)
# Out:
#                       %ID/g                                           \
#                     1_%ID/g    4_%ID/g  24_%ID/g  72_%ID/g 120_%ID/g
# Adrenals           0.607420   0.281980  0.156010  0.132230  0.071510
# Bladder          362.351720  48.905880  1.126880  0.280690  0.077120
# Bone Surfaces      0.118600   0.084720  0.067060  0.051440  0.040770
# Brain              0.043870   0.019630  0.003640  0.001950  0.000720
# Fat                0.152200   0.058710  0.026000  0.011140  0.006610
# Heart              0.448930   0.210780  0.082610  0.039260  0.021660
# Heart Contents     1.763400   0.835640  0.192990  0.052230  0.017520
# Kidneys            3.457020   3.042130  1.244180  0.441920  0.230620
# Left Colon         0.408980   0.416680  0.382560  0.072050  0.017440
# Liver              0.666630   0.531960  0.261200  0.148720  0.095690
# Lungs              2.191190   1.426680  0.224090  0.091910  0.043790
# Muscle             0.219340   0.096930  0.031030  0.014890  0.008360
# Pancreas           1.075470   0.207200  0.073500  0.025980  0.011600
# Rectum             0.408980   0.416680  0.382560  0.072050  0.017440
# Red Marrow         0.599556   0.284118  0.065617  0.017758  0.005957
# Right Colon        0.408980   0.416680  0.382560  0.072050  0.017440
# Seminals           0.135420   0.055730  0.019570  0.026850  0.006930
# Small Intestine    0.408980   0.416680  0.382560  0.072050  0.017440
# Spleen             0.313410   0.225050  0.148340  0.134630  0.081730
# Stomach            0.310490   0.108000  0.246210  0.020340  0.013570
# Tail               0.708600   0.381040  0.129550  0.092770  0.140100
# Testes             0.449790   0.230300  0.110660  0.061850  0.048630
# Tumor              8.671840   4.714900  1.593380  0.797950  0.391660
#
#                       sigma
#                        1_sd       4_sd     24_sd     72_sd    120_sd
# Adrenals           0.277570   0.070550  0.019580  0.087260  0.046650
# Bladder          138.443130  21.853480  0.514380  0.098450  0.029010
# Bone Surfaces      0.018760   0.025150  0.016720  0.008070  0.008530
# Brain              0.003170   0.004100  0.000570  0.001200  0.000200
# Fat                0.037510   0.008230  0.008010  0.004240  0.003040
# Heart              0.057520   0.033390  0.008310  0.008110  0.003140
# Heart Contents     0.142140   0.033200  0.014860  0.009100  0.003410
# Kidneys            0.286580   0.343710  0.158120  0.052730  0.065910
# Left Colon         0.235000   0.091790  0.226110  0.056860  0.010950
# Liver              0.070630   0.037780  0.014860  0.017330  0.039950
# Lungs              0.925290   0.335000  0.029720  0.010580  0.016390
# Muscle             0.014610   0.018520  0.003380  0.001840  0.000800
# Pancreas           0.219340   0.012320  0.014400  0.005310  0.002620
# Rectum             0.235000   0.091790  0.226110  0.056860  0.010950
# Red Marrow         0.048328   0.011288  0.005052  0.003094  0.001159
# Right Colon        0.235000   0.091790  0.226110  0.056860  0.010950
# Seminals           0.015860   0.008750  0.004560  0.033570  0.002850
# Small Intestine    0.235000   0.091790  0.226110  0.056860  0.010950
# Spleen             0.028670   0.041110  0.026560  0.038910  0.037900
# Stomach            0.172370   0.052800  0.148610  0.001650  0.010730
# Tail               0.116590   0.073810  0.028450  0.031390  0.133720
# Testes             0.112700   0.035800  0.014140  0.029490  0.010880
# Tumor              0.524710   0.317460  0.241090  0.141520  0.137710

# %%
human.fit_accepted
# Out:
# {'Adrenals': 2,
#  'Bladder': 2,
#  'Heart Contents': 2,
#  'Red Marrow': 2,
#  'Brain': 1,
#  'Fat': 2,
#  'Heart': 2,
#  'Kidneys': 2,
#  'Left Colon': 3,
#  'Right Colon': 3,
#  'Rectum': 3,
#  'Liver': 2,
#  'Lungs': 2,
#  'Muscle': 1,
#  'Pancreas': 2,
#  'Seminals': 2,
#  'Bone Surfaces': 2,
#  'Small Intestine': 2,
#  'Spleen': 2,
#  'Stomach': 1,
#  'Tail': 2,
#  'Testes': 2,
#  'Tumor': 2}

# %%
human.num_decays(human.fit_accepted)
human.disintegrations
# Out:
#                      %ID/g*h
# Adrenals           26.424042
# Bladder          1123.230044
# Bone Surfaces       14.73275
# Brain               0.215292
# Fat                 0.664734
# Heart               9.433624
# Heart Contents     19.721571
# Kidneys           120.237812
# Left Colon         21.444802
# Liver              33.241395
# Lungs              31.322317
# Muscle               1.06854
# Pancreas            8.538317
# Rectum             21.444802
# Red Marrow          6.705334
# Right Colon        21.444802
# Seminals            2.770882
# Small Intestine     6.296961
# Spleen             33.626663
# Stomach             1.266838
# Tail               29.654687
# Testes             16.733187
# Tumor             184.189864
# Remainder Body           NaN

# %%
human.phantom_data()
human.phantom_mass
# Out:
# /home/skurkowska/doodle/doodle/preclinical_dosimetry/phantomdata
# These organs from the biodi are not modelled in the phantom
# ['Fat', 'Muscle', 'Seminals', 'Tail', 'Tumor']
#
# These organs modelled in the phantom were not included in the biodistribution.
# ['Breasts', 'Esophagus', 'Eyes', 'Gallbladder', 'Ovaries', 'Prostate', 'Salivary Glands', 'Thymus', 'Thyroid', 'Uterus']
#                  Female   Male
# Organ
# Adrenals             13     14
# Bladder              40     50
# Body              60000  73000
# Bone Surfaces       120    120
# Brain              1300   1450
# Breasts             500     25
# Esophagus            35     40
# Eyes                 15     15
# Gallbladder           8     10
# Heart               250    330
# Heart Contents      370    510
# Kidneys             275    310
# Left Colon          145    150
# Liver              1400   1800
# Lungs               950   1200
# Ovaries              11      0
# Pancreas            120    140
# Prostate              0     17
# Rectum               70     70
# Red Marrow          900   1170
# Right Colon         145    150
# Salivary Glands      70     85
# Small Intestine     600    650
# Spleen              130    150
# Stomach             140    150
# Testes                0     35
# Thymus               20     25
# Thyroid              17     20
# Uterus               80      0
# Remainder Body    53032  64551

# %%
human.remainder_body_uptake()
# Out:
# At this point we are ignoring the tumor
# AdultHuman
# Disintegrations
#
#
# Literature Mass (g)
#
#            Female     Male
# Fat       16989.0  15169.4
# Muscle    17500.0  29000.0
# Seminals      0.0      6.4
#                  Female   Male
# Organ
# Adrenals             13     14
# Bladder              40     50
# Body              60000  73000
# Bone Surfaces       120    120
# Brain              1300   1450
# Breasts             500     25
# Esophagus            35     40
# Eyes                 15     15
# Gallbladder           8     10
# Heart               250    330
# Heart Contents      370    510
# Kidneys             275    310
# Left Colon          145    150
# Liver              1400   1800
# Lungs               950   1200
# Ovaries              11      0
# Pancreas            120    140
# Prostate              0     17
# Rectum               70     70
# Red Marrow          900   1170
# Right Colon         145    150
# Salivary Glands      70     85
# Small Intestine     600    650
# Spleen              130    150
# Stomach             140    150
# Testes                0     35
# Thymus               20     25
# Thyroid              17     20
# Uterus               80      0
# Remainder Body    53032  64551

# %%
human.disintegrations
# Out:
#                   %ID/g*h %ID*h Female  %ID*h Male
# Adrenals          0.26424     3.435125    3.699366
# Bladder           11.2323   449.292017  561.615022
# Bone Surfaces    0.147327      17.6793     17.6793
# Brain            0.002153     2.798797    3.121735
# Heart            0.094336     23.58406   31.130959
# Heart Contents   0.197216    72.969814  100.580014
# Kidneys          1.202378   330.653984  372.737218
# Left Colon       0.214448    31.094963   32.167203
# Liver            0.332414   465.379536  598.345117
# Lungs            0.313223   297.562015  375.867808
# Pancreas         0.085383     10.24598   11.953644
# Rectum           0.214448    15.011362   15.011362
# Red Marrow       0.067053    60.348008   78.452411
# Right Colon      0.214448    31.094963   32.167203
# Small Intestine   0.06297    37.781768   40.930249
# Spleen           0.336267    43.714662   50.439994
# Stomach          0.012668     1.773573    1.900257
# Testes           0.167332          0.0    5.856615
# Remainder Body        NaN   299.926271  410.890242

# %% [markdown]
# ### M2: Extrapolation of TIAC_H from TIAC_A applying a relative mass scaling factor (rMSF)

# %%
human.interspecies_conversion()

# %%
human.disintegrations
# Out:
#                   %ID/g*h %ID*h Female %ID*h Male
# Adrenals          0.26424     0.001431   0.001267
# Bladder           11.2323     0.187205   0.192334
# Bone Surfaces    0.147327     0.007366   0.006055
# Brain            0.002153     0.001166   0.001069
# Heart            0.094336     0.009827   0.010661
# Heart Contents   0.197216     0.030404   0.034445
# Kidneys          1.202378     0.137772    0.12765
# Left Colon       0.214448     0.012956   0.011016
# Liver            0.332414     0.193908   0.204913
# Lungs            0.313223     0.123984   0.128722
# Pancreas         0.085383     0.004269   0.004094
# Rectum           0.214448     0.006255   0.005141
# Red Marrow       0.067053     0.025145   0.026867
# Right Colon      0.214448     0.012956   0.011016
# Small Intestine   0.06297     0.015742   0.014017
# Spleen           0.336267     0.018214   0.017274
# Stomach          0.012668     0.000739   0.000651
# Testes           0.167332          0.0   0.002006
# Remainder Body        NaN     0.124969   0.140716

# %%
human.create_humancase(savefile=True,dirname=dirname)
# Out:
# The case file Male.cas has been saved in
# /mnt/y/Sara/Preclinical_dosimetry/PC3_04-11-2022_Lu177_GRPRtargeting_NRG_LeiWang-LW01090_updated

# %%
human.create_humancase(savefile=True,dirname=dirname)
# Out:
# The case file Male.cas has been saved in
# /mnt/y/Sara/Preclinical_dosimetry/PC3_04-11-2022_Lu177_GRPRtargeting_NRG_LeiWang-LW01090_updated
